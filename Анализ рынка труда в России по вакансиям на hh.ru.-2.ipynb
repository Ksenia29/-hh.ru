# %% [markdown]
# # Описание проекта и целей
#
#
# Необходимо было провести анализ рынка труда в России по вакансиям на hh.ru по запросам:
# - Аналитик данных
# - Бизнес Аналитик
#
# Целью работы является выявление различий в предлагаемых вакансиях.
#
# Необходимо проверить следующие гипотезы:
#
# - Большую долю вакансий занимают вакансии на позицию Junior с опытом от года.
# - Москва лидирует по количеству вакансий.
# - Предложений на удаленную работу больше чем на работу в офисе.
#
# Ход исследования
#
# Данные для анализа мы получим по следующей ссылке https://disk.yandex.ru/d/qVTeq4KBlHdA7g. О качестве данных ничего не известно. Поэтому перед проверкой гипотез понадобится обзор данных и скорей всего предобработка.
#
# Таким образом, исследование пройдёт в четыре этапа:
#
# 1. Обзор данных.
# 2. Предобработка данных.
# 3. Исследовательский анализ.
# 4. Выводы по проекту и проверка гипотез.

# %% [markdown]
# # Обзор данных

# %%
# импортируем необходимые библиотеки
# !pip install plotly
# !pip install openpyxl
import time
import warnings
import pandas as pd
import numpy as np
import seaborn as sns
import plotly.express as px
import matplotlib.pyplot as plt
from plotly import graph_objects as go
# %matplotlib inline

from datetime import datetime
from datetime import date, timedelta as td
from datetime import datetime, timedelta
# для визуализации
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.float_format', '{:.2f}'.format)
warnings.filterwarnings(action='ignore')
# Out:
# Requirement already satisfied: plotly in ./anaconda3/lib/python3.11/site-packages (5.9.0)
# Requirement already satisfied: tenacity>=6.2.0 in ./anaconda3/lib/python3.11/site-packages (from plotly) (8.2.2)
# Requirement already satisfied: openpyxl in ./anaconda3/lib/python3.11/site-packages (3.0.10)
# Requirement already satisfied: et_xmlfile in ./anaconda3/lib/python3.11/site-packages (from openpyxl) (1.1.0)

# %%
# загружаем данные 
data_da = pd.read_excel('/Users/kseniaadzic/Downloads/vacancies_da.xlsx')
display(data_da.info())
data_ba = pd.read_excel('/Users/kseniaadzic/Downloads/vacancies_ba.xlsx')
display(data_ba.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 417 entries, 0 to 416
# Data columns (total 20 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   id                                417 non-null    int64
#  1   name                              417 non-null    object
#  2   published_at                      417 non-null    datetime64[ns]
#  3   alternate_url                     417 non-null    object
#  4   type                              417 non-null    object
#  5   employer                          417 non-null    object
#  6   department                        137 non-null    object
#  7   area                              417 non-null    object
#  8   experience                        417 non-null    object
#  9   key_skills                        417 non-null    object
#  10  schedule                          417 non-null    object
#  11  employment                        417 non-null    object
#  12  description                       417 non-null    object
#  13  description_lemmatized            417 non-null    object
#  14  salary_from                       57 non-null     float64
#  15  salary_to                         30 non-null     float64
#  16  salary_bin                        417 non-null    object
#  17  key_skills_from_key_skills_field  237 non-null    object
#  18  hard_skills_from_description      91 non-null     object
#  19  soft_skills_from_description      135 non-null    object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(16)
# memory usage: 65.3+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1011 entries, 0 to 1010
# Data columns (total 20 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   id                                1011 non-null   int64
#  1   name                              1011 non-null   object
#  2   published_at                      1011 non-null   datetime64[ns]
#  3   alternate_url                     1011 non-null   object
#  4   type                              1011 non-null   object
#  5   employer                          1011 non-null   object
#  6   department                        210 non-null    object
#  7   area                              1011 non-null   object
#  8   experience                        1011 non-null   object
#  9   key_skills                        1011 non-null   object
#  10  schedule                          1011 non-null   object
#  11  employment                        1011 non-null   object
#  12  description                       1011 non-null   object
#  13  description_lemmatized            1011 non-null   object
#  14  salary_from                       172 non-null    float64
#  15  salary_to                         132 non-null    float64
#  16  salary_bin                        1011 non-null   object
#  17  key_skills_from_key_skills_field  566 non-null    object
#  18  hard_skills_from_description      167 non-null    object
#  19  soft_skills_from_description      618 non-null    object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(16)
# memory usage: 158.1+ KB
# None

# %%
# обработаем 1-ый датафрейм 
data_da.shape
# Out:
# (417, 20)

# %%
# преобразуем столбец name и удалим строки со словами системный и bi
data_da.name = data_da.name.str.lower()
data_da.name = data_da.name.str.strip()
data_da.name = data_da.name.str.replace('-',' ')
data_da.name = data_da.name.str.replace('/', ' ')
data_da = data_da[~data_da.name.str.contains('системный') & ~data_da.name.str.contains('bi')]
data_da.shape
# Out:
# (375, 20)

# %%
# преобразуем столбец name и удалим строки со словами системный и bi во втором датафрейме
data_ba.name = data_ba.name.str.lower()
data_ba.name = data_ba.name.str.strip()
data_ba.name = data_ba.name.str.replace('-',' ')
data_ba.name = data_ba.name.str.replace('/', ' ')
data_ba = data_ba[~data_ba.name.str.contains('системный') & ~data_ba.name.str.contains('bi')]
#data_ba.name.value_counts() 
data_ba.shape
#data_ba.isna().sum()
# Out:
# (925, 20)

# %%
# соединим два датафрейма
df = pd.concat([data_da, data_ba], axis=0)
df.shape
# Out:
# (1300, 20)

# %% [markdown]
# объединение прошло успешно

# %%
# создадим функцию для получения общей информации по датафрейму
def df_review(df):
    start = "\033[1m"
    end2 = "\033[0;0m"
    print(start + f'Вывод инфо' + end2, end='\n\n')
    print(df.info())
    print('---------------------------------------------------------------------------------------------------------')
    print(start + f'Вывод описания' + end2, end='\n\n')
    print(df.describe())
    print('---------------------------------------------------------------------------------------------------------')
    print(start + f'Количество пропусков' + end2, end='\n\n')
    print(df.isna().sum())
    print('---------------------------------------------------------------------------------------------------------')
    print(start + f'Количество пропусков в процентах' + end2, end='\n\n')
    display(pd.DataFrame(round(df.isna().mean()*100,)).style.background_gradient('coolwarm'))
    print('---------------------------------------------------------------------------------------------------------')
    print(start + f'Количество дублей' + end2, end='\n\n')
    print(df.duplicated().sum())

# %%
df_review(df)
# Out:
# Вывод инфо
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1300 entries, 0 to 1010
# Data columns (total 20 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   id                                1300 non-null   int64
#  1   name                              1300 non-null   object
#  2   published_at                      1300 non-null   datetime64[ns]
#  3   alternate_url                     1300 non-null   object
#  4   type                              1300 non-null   object
#  5   employer                          1300 non-null   object
#  6   department                        313 non-null    object
#  7   area                              1300 non-null   object
#  8   experience                        1300 non-null   object
#  9   key_skills                        1300 non-null   object
#  10  schedule                          1300 non-null   object
#  11  employment                        1300 non-null   object
#  12  description                       1300 non-null   object
#  13  description_lemmatized            1300 non-null   object
#  14  salary_from                       212 non-null    float64
#  15  salary_to                         143 non-null    float64
#  16  salary_bin                        1300 non-null   object
#  17  key_skills_from_key_skills_field  711 non-null    object
#  18  hard_skills_from_description      233 non-null    object
#  19  soft_skills_from_description      670 non-null    object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(16)
# memory usage: 213.3+ KB
# None
# ---------------------------------------------------------------------------------------------------------
# Вывод описания
#
#                id  salary_from  salary_to
# count     1300.00       212.00     143.00
# mean  94269447.49    113914.23  166508.80
# std    2004534.75     61217.13   84256.90
# min   77320677.00     28940.00   36175.00
# 25%   93809800.00     70000.00  100000.00
# 50%   94979252.00    100000.00  150000.00
# 75%   95437818.00    142500.00  203500.00
# max   95846083.00    350000.00  400000.00
# ---------------------------------------------------------------------------------------------------------
# Количество пропусков
#
# id                                     0
# name                                   0
# published_at                           0
# alternate_url                          0
# type                                   0
# employer                               0
# department                           987
# area                                   0
# experience                             0
# key_skills                             0
# schedule                               0
# employment                             0
# description                            0
# description_lemmatized                 0
# salary_from                         1088
# salary_to                           1157
# salary_bin                             0
# key_skills_from_key_skills_field     589
# hard_skills_from_description        1067
# soft_skills_from_description         630
# dtype: int64
# ---------------------------------------------------------------------------------------------------------
# Количество пропусков в процентах
# <style type="text/css">
# #T_50330_row0_col0, #T_50330_row1_col0, #T_50330_row2_col0, #T_50330_row3_col0, #T_50330_row4_col0, #T_50330_row5_col0, #T_50330_row7_col0, #T_50330_row8_col0, #T_50330_row9_col0, #T_50330_row10_col0, #T_50330_row11_col0, #T_50330_row12_col0, #T_50330_row13_col0, #T_50330_row16_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_50330_row6_col0 {
#   background-color: #e36b54;
#   color: #f1f1f1;
# }
# #T_50330_row14_col0 {
#   background-color: #c83836;
#   color: #f1f1f1;
# }
# #T_50330_row15_col0 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_50330_row17_col0 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_50330_row18_col0 {
#   background-color: #d0473d;
#   color: #f1f1f1;
# }
# #T_50330_row19_col0 {
#   background-color: #e7d7ce;
#   color: #000000;
# }
# </style>
# <table id="T_50330">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_50330_level0_col0" class="col_heading level0 col0" >0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_50330_level0_row0" class="row_heading level0 row0" >id</th>
#       <td id="T_50330_row0_col0" class="data row0 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_50330_level0_row1" class="row_heading level0 row1" >name</th>
#       <td id="T_50330_row1_col0" class="data row1 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_50330_level0_row2" class="row_heading level0 row2" >published_at</th>
#       <td id="T_50330_row2_col0" class="data row2 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_50330_level0_row3" class="row_heading level0 row3" >alternate_url</th>
#       <td id="T_50330_row3_col0" class="data row3 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_50330_level0_row4" class="row_heading level0 row4" >type</th>
#       <td id="T_50330_row4_col0" class="data row4 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_50330_level0_row5" class="row_heading level0 row5" >employer</th>
#       <td id="T_50330_row5_col0" class="data row5 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_50330_level0_row6" class="row_heading level0 row6" >department</th>
#       <td id="T_50330_row6_col0" class="data row6 col0" >76.000000</td>
#     </tr>
#     <tr>
#       <th id="T_50330_level0_row7" class="row_heading level0 row7" >area</th>
#       <td id="T_50330_row7_col0" class="data row7 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_50330_level0_row8" class="row_heading level0 row8" >experience</th>
#       <td id="T_50330_row8_col0" class="data row8 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_50330_level0_row9" class="row_heading level0 row9" >key_skills</th>
#       <td id="T_50330_row9_col0" class="data row9 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_50330_level0_row10" class="row_heading level0 row10" >schedule</th>
#       <td id="T_50330_row10_col0" class="data row10 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_50330_level0_row11" class="row_heading level0 row11" >employment</th>
#       <td id="T_50330_row11_col0" class="data row11 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_50330_level0_row12" class="row_heading level0 row12" >description</th>
#       <td id="T_50330_row12_col0" class="data row12 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_50330_level0_row13" class="row_heading level0 row13" >description_lemmatized</th>
#       <td id="T_50330_row13_col0" class="data row13 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_50330_level0_row14" class="row_heading level0 row14" >salary_from</th>
#       <td id="T_50330_row14_col0" class="data row14 col0" >84.000000</td>
#     </tr>
#     <tr>
#       <th id="T_50330_level0_row15" class="row_heading level0 row15" >salary_to</th>
#       <td id="T_50330_row15_col0" class="data row15 col0" >89.000000</td>
#     </tr>
#     <tr>
#       <th id="T_50330_level0_row16" class="row_heading level0 row16" >salary_bin</th>
#       <td id="T_50330_row16_col0" class="data row16 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_50330_level0_row17" class="row_heading level0 row17" >key_skills_from_key_skills_field</th>
#       <td id="T_50330_row17_col0" class="data row17 col0" >45.000000</td>
#     </tr>
#     <tr>
#       <th id="T_50330_level0_row18" class="row_heading level0 row18" >hard_skills_from_description</th>
#       <td id="T_50330_row18_col0" class="data row18 col0" >82.000000</td>
#     </tr>
#     <tr>
#       <th id="T_50330_level0_row19" class="row_heading level0 row19" >soft_skills_from_description</th>
#       <td id="T_50330_row19_col0" class="data row19 col0" >48.000000</td>
#     </tr>
#   </tbody>
# </table>
# ---------------------------------------------------------------------------------------------------------
# Количество дублей
#
# 16

# %% [markdown]
# **Выводы по обзору данных:**
# 1. Вначале мы загрузили два датасета с вакансиями аналитик данных и бизнес аналитик;
# 2. Сразу удалили строки со словами 'системный' и 'bi', так как эти направления нас не интересуют;
# 3. Далее объединили два датафрейма в один.
# 4. В новом датафрейме 1300 вакансий с 20 характеристиками.
# 5. Имеются пропуски в категориальных данных, а также в зарплате.
# 6. Выявлено 16 явных дубликатов.
#
# Приступим к предобработке данных.

# %% [markdown]
# # Предобработка данных

# %%
# изменим типы данных где это необходимо
df.id = df.id.astype(object)
df.published_at = pd.to_datetime(df.published_at).dt.date

df.head()
# Out:
#          id                                               name published_at  \
# 0  77320677            управляющий эксперт по аналитике данных   2024-03-18
# 2  79889558  аналитик данных в группу управления метаданным...   2024-03-16
# 3  82901165                                      data аналитик   2024-03-25
# 7  87684971                                    аналитик данных   2024-03-18
# 8  88605313                                       data analyst   2024-03-12
#
#                     alternate_url      type  \
# 0  https://hh.ru/vacancy/77320677  Открытая
# 2  https://hh.ru/vacancy/79889558  Открытая
# 3  https://hh.ru/vacancy/82901165  Открытая
# 7  https://hh.ru/vacancy/87684971  Открытая
# 8  https://hh.ru/vacancy/88605313  Открытая
#
#                                             employer               department  \
# 0                          ПСБ (ПАО «Промсвязьбанк»)  ПАО «Промсвязьбанк», ИТ
# 2                                                МТС           «МТС», Digital
# 3                                              ЭлРос                      NaN
# 7  Кадровый Центр Департамента здравоохранения го...                      NaN
# 8                           Бланк – банк для бизнеса                      NaN
#
#        area           experience  \
# 0    Москва   Middle (3-6 years)
# 2    Москва  Junior+ (1-3 years)
# 3  Владимир  Junior+ (1-3 years)
# 7    Москва  Junior+ (1-3 years)
# 8    Москва  Junior+ (1-3 years)
#
#                                           key_skills          schedule  \
# 0  ['Бизнес-анализ', 'Анализ бизнес показателей',...       Полный день
# 2  ['Data Catalog', 'Data Governance', 'DMBOK DAM...       Полный день
# 3  ['Spark', 'Data Analysis', 'Теория вероятносте...       Полный день
# 7  ['Аналитическое мышление', 'MS Excel', 'MS Pow...       Полный день
# 8  ['Power BI', 'PowerBI', 'Tableau', 'PostgreSQL...  Удаленная работа
#
#          employment                                        description  \
# 0  Полная занятость  на масштабный проект по созданию единого корпо...
# 2  Полная занятость  мтс – это мультисервисная цифровая экосистема....
# 3  Полная занятость  наши преимущества:   аккредитованная ит-компан...
# 7  Полная занятость  обязанности:  анализ данных по заданным критер...
# 8  Полная занятость  привет!мы – бланк, современный life-first моби...
#
#                               description_lemmatized  salary_from  salary_to  \
# 0  масштабный проект создание единый корпоративны...          NaN        NaN
# 2  мтс мультисервисный цифровой экосистема создав...          NaN        NaN
# 3  наш преимущество аккредитовать ита компания си...          NaN        NaN
# 7  обязанность анализ данные заданный критерий по...    100000.00        NaN
# 8  привет бланк современный life first мобильный ...          NaN        NaN
#
#       salary_bin                   key_skills_from_key_skills_field  \
# 0  ЗП не указана  Финансовый анализ, Бизнес-анализ, Финансовая о...
# 2  ЗП не указана  Data Catalog, DMBOK DAMA, Business Glossary, D...
# 3  ЗП не указана  Python, Математическая статистика, SQL, Spark,...
# 7  ЗП не указана  MS Excel, Аналитика, MS PowerPoint, Анализ дан...
# 8  ЗП не указана  SQL, Python, Power BI, PowerBI, DAX, MS Power ...
#
#   hard_skills_from_description soft_skills_from_description
# 0                          NaN                 Документация
# 2                          NaN                          NaN
# 3                          NaN                          NaN
# 7                          NaN                          NaN
# 8                          NaN                          NaN

# %%
# удалим дубликаты
df = df.drop_duplicates()
df.duplicated().sum()
# Out:
# 0

# %%
df.columns
# Out:
# Index(['id', 'name', 'published_at', 'alternate_url', 'type', 'employer',
#        'department', 'area', 'experience', 'key_skills', 'schedule',
#        'employment', 'description', 'description_lemmatized', 'salary_from',
#        'salary_to', 'salary_bin', 'key_skills_from_key_skills_field',
#        'hard_skills_from_description', 'soft_skills_from_description'],
#       dtype='object')

# %% [markdown]
# Для удобства создадим столбец, который будет содержать наименование вакансии(либо аналитик данных либо бизнес аналитик)

# %%
# создадим новый столбец, содержащий наименование вакансии 
df['name'] = df['name'].str.replace('business', 'бизнес')
df['category'] = np.where(df['name'].str.contains('бизнес'), 'бизнес аналитик', 'аналитик данных')
df['category'].value_counts()
# Out:
# бизнес аналитик    926
# аналитик данных    358
# Name: category, dtype: int64

# %%
print('Из {} вакансий величина ЗП указана в {} случаях ({:.2%})'.format(len(df), df['salary_to'].count(), df['salary_to'].count()/len(df)))
print('Из {} вакансий ключевые навыки указаны в {} случаях ({:.2%})'.format(len(df), df['key_skills_from_key_skills_field'].count(), df['key_skills_from_key_skills_field'].count()/len(df)))
print('Всего компаний в выгрузке: {}'.format(len(df['employer'].unique())))
# Out:
# Из 1284 вакансий величина ЗП указана в 142 случаях (11.06%)
# Из 1284 вакансий ключевые навыки указаны в 701 случаях (54.60%)
# Всего компаний в выгрузке: 640

# %% [markdown]
# Заполним пропуски в категориальных столбцах словом 'неизвестно', в столбцах о зарплате пропуски составляют 89%. Принято решение заполнить 0, так как медианными значениями заполнять не имеет смысла, будет сильное искажение данных.

# %%
# заполним пропуски в датафрайме
df.key_skills_from_key_skills_field = df.key_skills_from_key_skills_field.fillna('неизвестно')
df.department = df.department.fillna('неизвестно')
df.salary_from = df.salary_from.fillna(0)
df.salary_to = df.salary_to.fillna(0)
df.hard_skills_from_description = df.hard_skills_from_description.fillna('неизвестно')
df.soft_skills_from_description = df.soft_skills_from_description.fillna('неизвестно')
#проверим 
df.isna().sum()
# Out:
# id                                  0
# name                                0
# published_at                        0
# alternate_url                       0
# type                                0
# employer                            0
# department                          0
# area                                0
# experience                          0
# key_skills                          0
# schedule                            0
# employment                          0
# description                         0
# description_lemmatized              0
# salary_from                         0
# salary_to                           0
# salary_bin                          0
# key_skills_from_key_skills_field    0
# hard_skills_from_description        0
# soft_skills_from_description        0
# category                            0
# dtype: int64

# %% [markdown]
# Далее приступим к дальнейшей предообработке столбцов датафрейма

# %%
#проверим стобец type и приведем к нижнему регистру и удалим лишние пробелы
df.type = df.type.str.lower()
df.type = df.type.str.strip()
df.type.value_counts()
# Out:
# открытая    1284
# Name: type, dtype: int64

# %%
# столбец employer приведем к нижнему регистру и удалим лишние пробелы
df.employer = df.employer.str.lower()
df.employer = df.employer.str.strip()
df.employer.value_counts().head(15)
# Out:
# сбер                         95
# магнит, розничная сеть       30
# банк втб (пао)               24
# т1                           23
# ozon                         15
# мтс                          14
# комус                        14
# aston                        11
# axenix (ранее accenture)     11
# правительство москвы         11
# wildberries                  11
# совкомбанк                   10
# технологии доверия           10
# газпром нефть                 9
# псб (пао «промсвязьбанк»)     9
# Name: employer, dtype: int64

# %%
df.department = df.department.str.lower()
df.department = df.department.str.strip()
df.department.value_counts().head(15)
# Out:
# неизвестно                                      974
# сбер для экспертов                               83
# гк иннотех | финтех (иннотех)                    13
# пао втб, средний и малый бизнес                  12
# ozon офис и коммерция                             9
# «мтс»                                             9
# технологии доверия, ит и цифровые технологии      8
# сбер. it                                          8
# газпромбанк                                       8
# пао «промсвязьбанк», бизнес и инфраструктура      7
# пао «газпром нефть» ит                            6
# яндекс                                            6
# северсталь. it & digital                          6
# гк иннотех | большие данные                       6
# мегафон, офис                                     6
# Name: department, dtype: int64

# %%
df.area = df.area.str.lower()
df.area = df.area.str.strip()
df.area.value_counts().head(15)
# Out:
# москва             801
# санкт-петербург    123
# екатеринбург        33
# нижний новгород     29
# казань              28
# краснодар           27
# самара              17
# новосибирск         17
# ростов-на-дону      13
# владивосток         10
# пермь                9
# воронеж              9
# тюмень               7
# саратов              7
# владимир             6
# Name: area, dtype: int64

# %%
df.experience = df.experience.str.lower()
df.experience = df.experience.str.strip()

df.experience.value_counts()
# Out:
# junior+ (1-3 years)      675
# middle (3-6 years)       505
# junior (no experince)     92
# senior (6+ years)         12
# Name: experience, dtype: int64

# %%
df.key_skills = df.key_skills.str.strip()
df.key_skills = df.key_skills.str.lower()

df.key_skills.value_counts().head(15)
# Out:
# []                                                                                                                                                                                                                                                                                                                                                259
# ['документация']                                                                                                                                                                                                                                                                                                                                  112
# ['документация', 'confluence']                                                                                                                                                                                                                                                                                                                     30
# ['коммуникация']                                                                                                                                                                                                                                                                                                                                   28
# ['pandas']                                                                                                                                                                                                                                                                                                                                         21
# ['документация', 'коммуникация']                                                                                                                                                                                                                                                                                                                   21
# ['аналитическое мышление']                                                                                                                                                                                                                                                                                                                         17
# ['confluence']                                                                                                                                                                                                                                                                                                                                     15
# ['документация', 'confluence', 'коммуникация']                                                                                                                                                                                                                                                                                                     10
# ['аналитическое мышление', 'документация']                                                                                                                                                                                                                                                                                                         10
# ['аналитическое мышление', 'документация', 'confluence']                                                                                                                                                                                                                                                                                            7
# ['аналитик 1с', 'бизнес-анализ', 'аналитический склад ума', 'автоматизация процессов управления персоналом', '1с: бухгалтерия', 'google docs', '1с: предприятие 8', 'моделирование бизнес процессов', '1с: управление персоналом', 'erp-системы на базе 1с', '1с: документооборот', 'ms office', '1с: зарплата и кадры', 'бухгалтерский учет']      6
# ['power bi', 'управление цепочкой поставок', 'ms sql', 'atlassian confluence', 'confluence', 'переговоры', 'ms visio', 'atlassian jira', 'архитектура бизнес-процессов', 'логистика', 'бизнес-планирование', 'документация', 'ms office']                                                                                                           6
# ['описание бизнес-процессов', 'ms powerpoint', 'ms outlook', 'кис', '1с: документооборот', 'подготовка презентаций', 'навыки презентации', 'уверенный пользователь ms office', 'документация']                                                                                                                                                      6
# ['аналитическое мышление', 'документация', 'коммуникация']                                                                                                                                                                                                                                                                                          5
# Name: key_skills, dtype: int64

# %%
df.schedule = df.schedule.str.lower()
df.schedule = df.schedule.str.strip()
df.schedule.value_counts()
# Out:
# полный день         1045
# удаленная работа     204
# гибкий график         32
# сменный график         3
# Name: schedule, dtype: int64

# %%
df.employment = df.employment.str.lower()
df.employment = df.employment.str.strip()
df.employment.value_counts()
# Out:
# полная занятость       1255
# стажировка               19
# частичная занятость       6
# проектная работа          4
# Name: employment, dtype: int64

# %%
df.description = df.description.str.lower()
df.description = df.description.str.strip()
df.description.value_counts().head(2)
# Out:
# компания axenix (ранее accenture) продолжает работу на российском рынке и аккумулирует 30-ти летний консалтинговый опыт внедрения инновационных решений.наша экспертиза - стратегия и консалтинг, технологии и операции, направленные на цифровизацию бизнеса. в своей деятельности мы сочетаем обширные знания, опыт в различных отраслях и глубокое понимание специфики и возможностей российского бизнеса. офисы компании находятся в москве, твери и ростове-на-дону, алматы и ереване.помимо этого, у нас есть команды в санкт-петербурге, краснодаре и воронеже, а также сотрудники, работающие удаленно из разных регионов.обязанности:  помощь в предоставлении стратегических консультаций и реализации проектов по трансформации бизнеса с помощью инновационных процессов и решений в области данных и искусственного интеллекта (ключевые индустрии – телеком, it, гос сектор) проведение исследований рынка больших данных и искусственного интеллекта, стратегических подходов к регулированию сферы и подходов к управлению данными и монетизации данных в различных странах и индустриях участие в разработке, расчете и защите коммерческих предложений для клиентов сбор, анализ и формализация требований от бизнеса в части стратегии данных и аналитики / дата-емких бизнес-кейсов / инструментов управления данными оценка текущего состояния функции данных и аналитики с использованием общепризнанных мировых подходов (dama, dcam, и пр.), формулировка целевого состояние, проработка карты инициатив по достижению целевого состояния совместно с представителями клиента проведение детального анализа данных в предметной области клиента с использованием внутренних и внешних источников информации, контентное наполнение и актуализация бизнес-глоссария/ каталога данных помощь в создании и поддержании систем управления данными, участие в планировании и разработке стратегии клиента, разработке и преобразовании корпоративных процессов, составлении планов, концепций высокоуровневой архитектуры в области data &amp; ai разработка технической документации решений, оформление результатов исследований, разработанных стратегий и сопроводительных исследований в презентационные материалы  требования:  фундаментальное понимание аналитики данных, искусственного интеллекта и разработки стратегии и стремление развивать карьеру в сфере консалтинга высшее образование одного из ведущих университетов, предпочтительно – технические (информационные технологии, прикладная математика, и пр.) или бизнес-специальности (бизнес-информатика, экономика, и пр.) практический опыт работы в сфере анализа данных, управления данными, бизнес-исследований, консалтинге и других смежных областях знание основ методологии управления данными, мировых подходов к управлению данными (dama, dcam, и пр.) продвинутый уровень владения powerpoint и excel знание английского языка – от b1 и выше  тебе будет у нас интересно, если ты: нестандартно мыслишь умеешь экспериментировать готов убеждать и отстаивать свою точку зрения не боишься предлагать и продвигать новые решения готов эффективно работать в среде многообразия опыта и культур импровизируешь и быстро приспосабливаешься к изменениям ориентирован на личный и командный успех хочешь создавать эффективную рабочую среду и вдохновлять команду на достижение высоких результатов мы предлагаем:  конкурентоспособный уровень дохода и регулярное повышение по результатам performance review гибридный график работы дмс с первого дня работы, включая стоматологию, для сотрудника и его семьи дополнительные 5 дней оплачиваемого отпуска в год ежемесячная денежная компенсация на питание/содержание автомобиля программа корпоративных привилегий primezone (более 1000 ведущих поставщиков продуктов и услуг) возможность обучения и сертификации за счет компании спортивные и развлекательные мероприятия за счет компании корпоративная техника.    6
# мы приглашаем присоединиться к нашей команде автоматизации процессов и развития технологий бизнес-аналитика для участия в реализации высокотехнологичных проектов крупного логистического оператора. мы находимся в постоянном развитии наших собственных приложений, таких как wms, tms, yms, oms. у нас гибкая интеграционная платформа для обмена с клиентами, курьерскими компаниями, государственными регуляторами. также мы строим процессы для наших клиентов в части интеграции с маркетплейсами и другими сервисами в рамках оказания услуг фулфилмента. основные задачи:  лидировать процесс выстраивания модели, запуска и масштабирования направления (процессы с клиентами, в том числе ff, внутренние процессы компании). оптимизация технологических процессов производства, повышение их эффективности. оптимизация процессов по работе с проблемным товаром на всех этапах, снижение % брака и рекламаций. формировать и описывать изменения процессов. осуществлять выборочный контроль сбора биллинга, настраивать правильную логику учета операций. лидировать проекты посадки новых клиентов 3pl. обосновывать и рассчитывать эффективность планируемых технологий или решений. работа в команде со смежными подразделениями, с другими лидерами продуктовых направлений и с пользователями из операционных блоков.  наши пожелания:  опыт работы с фулфилмент и e-com направлением, выстраивание бизнес-процессов на складе с «нуля». понимаете складские процессы и процессы по управлению материальными потоками от приемки товара на склад до отгрузки со склада. разработка и внедрение системы складской автоматизации в области электронной коммерции, розничной торговли и тд. оценка эффективности процессов и оборудования, формирование и мотивация по рекомендациям для выбора оптимальных решений. способность самостоятельно находить информацию, анализировать с составлением экспертной оценки. ответственность, многозадачность, стрессоустойчивость.  будет плюсом, если:  работали с wms и понимаете взаимосвязи складских процессов с it-системами. понимаете, как улучшения процесса влияют на стоимость операций и временные рамки обработки грузов.  мы предлагаем:  работа в крупной стабильной компании с более, чем 30-летней историей, численность сотрудников более 600 человек. оформление с первого рабочего дня в соответствии с тк рф, полный соц. пакет. высокая официальная заработная плата, выплачивается 2 раза в месяц. уровни окладной и премиальной частей заработной платы обсуждаются с финальным кандидатом на собеседовании. график работы: пятидневная рабочая неделя с 8 до 17 часов или с 9 до 18 часов на выбор. работа в целеустремленной команде профессионалов и возможность лидировать крупные и интересные проекты. высокая скорость принятия решений и реализации намеченных планов. комфортные условия труда: уютный офис с кофемашиной, столовая на территории с домашней кухней, отсутствие строго дресс кода. единая площадка, где находятся складские комплексы и офис. место работы: г. пушкино, м-н клязьма ул. костомаровская д.5/1. возможны краткосрочные командировки. бесплатный корпоративный транспорт из городов пушкино, ивантеевка, красноармейск, от/до ж/д станции клязьма. охраняемая парковка на собственной территории компании.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      5
# Name: description, dtype: int64

# %%
df.description_lemmatized = df.description_lemmatized.str.lower()  
df.description_lemmatized = df.description_lemmatized.str.strip()  

df.description_lemmatized.value_counts().head(2)
# Out:
# компания axenix ранее accenture продолжать работа российский рынок аккумулировать 3 ти летний консалтинговый опыт внедрение инновационный решение наш экспертиза стратегия консалтинг технология операция направлять цифровизация бизнес свой деятельность сочетать обширный знание опыт различный отрасль глубокий понимание специфика возможность российский бизнес офис компания находиться москва тверь ростов дон алматы ереван помимо команда санкт петербург краснодар воронеж также сотрудник работать удаленный разный регион обязанность помощь предоставление стратегический консультация реализация проект трансформация бизнес помощь инновационный процесс решение область данные искусственный интеллект ключевой индустрия телеком it гос сектор проведение исследование рынок большой данные искусственный интеллект стратегический подход регулирование сфера подход управление данные монетизация данные различный страна индустрия участие разработка расчет защита коммерческий предложение клиент сбор анализ формализация требование бизнес часть стратегия данные аналитика дата емкий бизнес кейс инструмент управление данные оценка текущий состояние функция данные аналитика использование общепризнанный мировой подход dama dcam пр формулировка целевой состояние проработка карта инициатива достижение целевой состояние совместно представитель клиент проведение детальный анализ данные предметный область клиент использование внутренний внешний источник информация контентный наполнение актуализация бизнес глоссарий каталог данные помощь создание поддержание система управление данные участие планирование разработка стратегия клиент разработка преобразование корпоративный процесс составление план концепция высокоуровневый архитектура область data amp ai разработка технический документация решение оформление результат исследование разрабатывать стратегия сопроводительный исследование презентационный материал требование фундаментальный понимание аналитика данные искусственный интеллект разработка стратегия стремление развивать карьера сфера консалтинг высокий образование ведущий университет предпочтительно технический информационный технология прикладной математика пр бизнес специальность бизнес информатика экономика пр практический опыт работа сфера анализ данные управление данные бизнес исследование консалтинг смежный область знание основа методология управление данные мировой подход управление данные dama dcam пр продвигать уровень владение powerpoint excel знание английский язык b1 высоко интересно нестандартно мыслить уметь экспериментировать готовый убеждать отстаивать свой точка зрение бояться предлагать продвигать новый решение готовый эффективно работать среда многообразие опыт культура импровизировать быстро приспосабливаться изменение ориентировать личный командный успех хотеть создавать эффективный рабочий среда вдохновлять команда достижение высокий результат предлагать конкурентоспособный уровень доход регулярный повышение результат performance review гибридный график работа дмс первый день работа включая стоматология сотрудник семья дополнительный 5 день оплачивать отпуск год ежемесячный денежный компенсация питание содержание автомобиль программа корпоративный привилегия primezone 1 ведущий поставщик продукт услуга возможность обучение сертификация счет компания спортивный развлекательный мероприятие счет компания корпоративный техника    6
# обязанность координация процесс построение управленческий учет база информационный система формализация актуализация методология ведение управленческий учет формирование бюджетный показатель анализ технический возможность интеграционный связь использовать информационный система внедрение эксплуатация технология обработка информация рамка процесс автоматизация управленческий учет осуществление консалтинговый методологический поддержка участник процесс внедрение ведение управленческий учет технический сопровождение процесс внедрение решение часть построение автоматизация управленческий учет разработка рекомендация методический материал основа работа информационный система обучение пользователь основа работа действующий информационный система бюджетный форма формирование аналитический отчет требование уверенный знание бухгалтерский налоговый учет отчетность рсба мсфо высокий образование знание бюджетный процесс методология планирование бюджетирование учет распределение затрата знание экономика строительство знание документооборот часть учет выполнять работа объем нзп знание основа производственный планирование смр понимание структура распределение выполнение объем работа рамка проект знание принцип ресурсный планирование выполнение работа производство продукция оказание услуга опыт построение разработка ноль сложный финансовый модель возможность проведение сценарный анализ путем изменение входной параметр знание архитектура информационный система 1с упп 1с erp sap опыт часть структурирование наполнение нормативный справочный информация система осуществление контроль применение опыт формирование технический задание автоматизация учетный операция постановка задача ита специалист тестирование результат внедрение опыт построение координация бизнес процесс рамка внедрение сопровождение механизм ведение управленческий учет бюджетирование условие предлагать теплый атмосфера дружный компания четкий прозрачный процесс официальный трудоустройство предоставлять дмс поддерживать стремление развитие корпоративный английский различный профессиональный обучение направление работа заряжать корпоративный спорт волейбол футбол молодежный движение круг коллега место работа строительный площадка атомный электростанция эль дабаа египет предоставлять релокационный пакет                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   5
# Name: description_lemmatized, dtype: int64

# %%
df.salary_from.value_counts(normalize=True).mul(100).round(1).astype(str) + '%'
# Out:
# 0.00         83.6%
# 100000.00     2.6%
# 70000.00      1.7%
# 150000.00     1.2%
# 50000.00      1.2%
# 120000.00     1.2%
# 200000.00     0.8%
# 80000.00      0.7%
# 130000.00     0.5%
# 60000.00      0.5%
# 180000.00     0.5%
# 140000.00     0.4%
# 90000.00      0.4%
# 250000.00     0.4%
# 300000.00     0.3%
# 75000.00      0.3%
# 110000.00     0.3%
# 170000.00     0.2%
# 85000.00      0.2%
# 52000.00      0.2%
# 160000.00     0.2%
# 137000.00     0.2%
# 30000.00      0.2%
# 35000.00      0.2%
# 49000.00      0.1%
# 39000.00      0.1%
# 138000.00     0.1%
# 230000.00     0.1%
# 74600.00      0.1%
# 89000.00      0.1%
# 100328.00     0.1%
# 168000.00     0.1%
# 187000.00     0.1%
# 55215.00      0.1%
# 65000.00      0.1%
# 45000.00      0.1%
# 57500.00      0.1%
# 84000.00      0.1%
# 280000.00     0.1%
# 78439.00      0.1%
# 57000.00      0.1%
# 105000.00     0.1%
# 40050.00      0.1%
# 78200.00      0.1%
# 55000.00      0.1%
# 40000.00      0.1%
# 73000.00      0.1%
# 42500.00      0.1%
# 28940.00      0.1%
# 76000.00      0.1%
# 78045.00      0.1%
# 280500.00     0.1%
# 350000.00     0.1%
# 207000.00     0.1%
# Name: salary_from, dtype: object

# %%
df.salary_to.value_counts(normalize=True).mul(100).round(1).astype(str) + '%'
# Out:
# 0.00         88.9%
# 150000.00     1.3%
# 200000.00     1.0%
# 180000.00     0.9%
# 80000.00      0.8%
# 100000.00     0.6%
# 110000.00     0.6%
# 300000.00     0.5%
# 250000.00     0.5%
# 220000.00     0.3%
# 400000.00     0.2%
# 350000.00     0.2%
# 230000.00     0.2%
# 280000.00     0.2%
# 73000.00      0.2%
# 160000.00     0.2%
# 170000.00     0.2%
# 70000.00      0.2%
# 50000.00      0.2%
# 120000.00     0.2%
# 85000.00      0.2%
# 40000.00      0.2%
# 55000.00      0.2%
# 130000.00     0.2%
# 78200.00      0.1%
# 63000.00      0.1%
# 60000.00      0.1%
# 207000.00     0.1%
# 140000.00     0.1%
# 137000.00     0.1%
# 374000.00     0.1%
# 81379.00      0.1%
# 233750.00     0.1%
# 135000.00     0.1%
# 98000.00      0.1%
# 172000.00     0.1%
# 78045.00      0.1%
# 270000.00     0.1%
# 58500.00      0.1%
# 195000.00     0.1%
# 218400.00     0.1%
# 115000.00     0.1%
# 145931.00     0.1%
# 81000.00      0.1%
# 93750.00      0.1%
# 36175.00      0.1%
# 125000.00     0.1%
# 67629.00      0.1%
# 217000.00     0.1%
# Name: salary_to, dtype: object

# %%
df.salary_bin = df.salary_bin.str.lower()
df.salary_bin = df.salary_bin.str.strip()
df.salary_bin.value_counts(normalize=True).mul(100).round(1).astype(str) + '%'
# Out:
# зп не указана                88.9%
# от 100 тысяч до 200 тысяч     4.8%
# от 200 тысяч до 300 тысяч     2.6%
# меньше 100 тысяч              2.6%
# больше 300 тысяч              1.1%
# Name: salary_bin, dtype: object

# %%
df.key_skills_from_key_skills_field = df.key_skills_from_key_skills_field.str.lower()
df.key_skills_from_key_skills_field = df.key_skills_from_key_skills_field.str.strip()
df.key_skills_from_key_skills_field = df.key_skills_from_key_skills_field.str.replace('-',' ')
df.key_skills_from_key_skills_field = df.key_skills_from_key_skills_field.str.replace('/', ' ')

# %%
df.hard_skills_from_description = df.hard_skills_from_description.str.lower()
df.hard_skills_from_description = df.hard_skills_from_description.str.strip()
df.hard_skills_from_description = df.hard_skills_from_description.str.replace('-',' ')
df.hard_skills_from_description = df.hard_skills_from_description.str.replace('/', ' ')
df.hard_skills_from_description.value_counts()
# Out:
# неизвестно               1052
# confluence                159
# pandas                     59
# юнит экономика              9
# pandas, confluence          3
# pandas, google sheets       1
# google sheets               1
# Name: hard_skills_from_description, dtype: int64

# %%
# создадим функцию для преобразования списка списков в плоский список
def rad(col):
    result = []
    for element in col:
        if type(element) is list:
            for item in element:
                result.append(item)
        else:
            result.append(element)
    return result

 
df.key_skills_from_key_skills_field = rad(df.key_skills_from_key_skills_field)

df.head()
# Out:
#          id                                               name published_at  \
# 0  77320677            управляющий эксперт по аналитике данных   2024-03-18
# 2  79889558  аналитик данных в группу управления метаданным...   2024-03-16
# 3  82901165                                      data аналитик   2024-03-25
# 7  87684971                                    аналитик данных   2024-03-18
# 8  88605313                                       data analyst   2024-03-12
#
#                     alternate_url      type  \
# 0  https://hh.ru/vacancy/77320677  открытая
# 2  https://hh.ru/vacancy/79889558  открытая
# 3  https://hh.ru/vacancy/82901165  открытая
# 7  https://hh.ru/vacancy/87684971  открытая
# 8  https://hh.ru/vacancy/88605313  открытая
#
#                                             employer               department  \
# 0                          псб (пао «промсвязьбанк»)  пао «промсвязьбанк», ит
# 2                                                мтс           «мтс», digital
# 3                                              элрос               неизвестно
# 7  кадровый центр департамента здравоохранения го...               неизвестно
# 8                           бланк – банк для бизнеса               неизвестно
#
#        area           experience  \
# 0    москва   middle (3-6 years)
# 2    москва  junior+ (1-3 years)
# 3  владимир  junior+ (1-3 years)
# 7    москва  junior+ (1-3 years)
# 8    москва  junior+ (1-3 years)
#
#                                           key_skills          schedule  \
# 0  ['бизнес-анализ', 'анализ бизнес показателей',...       полный день
# 2  ['data catalog', 'data governance', 'dmbok dam...       полный день
# 3  ['spark', 'data analysis', 'теория вероятносте...       полный день
# 7  ['аналитическое мышление', 'ms excel', 'ms pow...       полный день
# 8  ['power bi', 'powerbi', 'tableau', 'postgresql...  удаленная работа
#
#          employment                                        description  \
# 0  полная занятость  на масштабный проект по созданию единого корпо...
# 2  полная занятость  мтс – это мультисервисная цифровая экосистема....
# 3  полная занятость  наши преимущества:   аккредитованная ит-компан...
# 7  полная занятость  обязанности:  анализ данных по заданным критер...
# 8  полная занятость  привет!мы – бланк, современный life-first моби...
#
#                               description_lemmatized  salary_from  salary_to  \
# 0  масштабный проект создание единый корпоративны...         0.00       0.00
# 2  мтс мультисервисный цифровой экосистема создав...         0.00       0.00
# 3  наш преимущество аккредитовать ита компания си...         0.00       0.00
# 7  обязанность анализ данные заданный критерий по...    100000.00       0.00
# 8  привет бланк современный life first мобильный ...         0.00       0.00
#
#       salary_bin                   key_skills_from_key_skills_field  \
# 0  зп не указана  финансовый анализ, бизнес анализ, финансовая о...
# 2  зп не указана  data catalog, dmbok dama, business glossary, d...
# 3  зп не указана  python, математическая статистика, sql, spark,...
# 7  зп не указана  ms excel, аналитика, ms powerpoint, анализ дан...
# 8  зп не указана  sql, python, power bi, powerbi, dax, ms power ...
#
#   hard_skills_from_description soft_skills_from_description         category
# 0                   неизвестно                 Документация  аналитик данных
# 2                   неизвестно                   неизвестно  аналитик данных
# 3                   неизвестно                   неизвестно  аналитик данных
# 7                   неизвестно                   неизвестно  аналитик данных
# 8                   неизвестно                   неизвестно  аналитик данных

# %%
df.soft_skills_from_description = df.soft_skills_from_description.str.lower()
df.soft_skills_from_description = df.soft_skills_from_description.str.strip()

df.soft_skills_from_description.value_counts().head(15)
# Out:
# неизвестно                                            620
# документация                                          340
# коммуникация                                           76
# аналитическое мышление                                 54
# коммуникация, документация                             54
# документация, аналитическое мышление                   36
# документация, переговоры                               20
# переговоры                                             16
# коммуникация, документация, аналитическое мышление     10
# проактивность                                           9
# креативность                                            5
# коммуникация, аналитическое мышление                    4
# документация, проактивность                             4
# документация, креативность                              3
# коммуникация, проактивность                             3
# Name: soft_skills_from_description, dtype: int64

# %%
df.columns
# Out:
# Index(['id', 'name', 'published_at', 'alternate_url', 'type', 'employer',
#        'department', 'area', 'experience', 'key_skills', 'schedule',
#        'employment', 'description', 'description_lemmatized', 'salary_from',
#        'salary_to', 'salary_bin', 'key_skills_from_key_skills_field',
#        'hard_skills_from_description', 'soft_skills_from_description',
#        'category'],
#       dtype='object')

# %% [markdown]
# **Выводы по предобработке:**
#
# 1. Были удалены явные дубликаты
# 2. Все данные приведены к нижнему регистру и удалены лишние пробелы.
# 3. Пропуски в категориальных данных заполнены словом 'неизвестно', в зарплате пропуски было решено заполнить значением 0, так как только 11% данных имеют данные по зарплате.
# 4. Был создан столбец 'category', который мы заполнили общими названиями вакансий(аналитик данных и бизнес аналитик) из столбца 'name'.
# 5. Столбец 'key_skills_from_key_skills_field' имел тип список списков, поэтому для облегчения работы с ним, мы создали функцию для изменения списка списков в плоский список.
# 6. Столбец 'published_at' был приведен к формату date.
# 7. Данные все готовы для дальнейшего анализа.

# %% [markdown]
# # Исследовательский анализ

# %% [markdown]
# Вначале предполагается провести исследовательский анализ данных, и потом в выводах осуществить проверку выдвинутых гипотез.

# %% [markdown]
# ## ТОП ключевых навыков требуемых в вакансиях Аналитик данных и Бизнес аналитик

# %%
df['skills_list'] = df['key_skills_from_key_skills_field'].apply(lambda x: x.split(', '))
df

skills_list = []
skills_data_analyst = []
skills_business_analyst = []

lists = {
    'аналитик данных':skills_data_analyst,
    'бизнес аналитик':skills_business_analyst
}


for keyword in lists:
    for skills in df.query('category==@keyword')['skills_list']:
        for skill in skills:
            if skill!='неизвестно':
                lists[keyword].append(skill)

skills_list = skills_data_analyst + skills_business_analyst
  

skills_data_analyst_df = pd.DataFrame({'skill':skills_data_analyst})
skills_business_analyst_df = pd.DataFrame({'skill':skills_business_analyst})
skills = pd.DataFrame({'skill':skills_list})

skills_data_analyst_df = pd.DataFrame(skills_data_analyst_df['skill'].value_counts()).reset_index()
skills_business_analyst_df = pd.DataFrame(skills_business_analyst_df['skill'].value_counts()).reset_index()
skills = pd.DataFrame(skills['skill'].value_counts()).reset_index()

skills_data_analyst_df.columns = ['skill', 'vacancies']
skills_business_analyst_df.columns = ['skill', 'vacancies']
skills.columns = ['skill', 'vacancies']

skills_data_analyst_df['percent_of_vacancies'] = skills_data_analyst_df['vacancies'] / len(df.query('key_skills_from_key_skills_field != "неизвестно" and category=="аналитик данных"'))
skills_business_analyst_df['percent_of_vacancies'] = skills_business_analyst_df['vacancies'] / len(df.query('key_skills_from_key_skills_field != "неизвестно" and category=="бизнес аналитик"'))
skills['percent_of_vacancies'] = skills['vacancies'] / len(df.query('key_skills_from_key_skills_field != "неизвестно"'))

lists_for_plots = {
    'аналитик данных':skills_data_analyst_df,
    'бизнес аналитик':skills_business_analyst_df, 
    'аналитик данных / бизнес аналитик':skills
}

for keyword in lists_for_plots:
    fig = px.bar(lists_for_plots[keyword].head(15), x='skill', y='vacancies', width = 950, height = 450, color='skill', text='vacancies')
    fig.update_xaxes(tickangle=30)
    fig.update_layout(
        title='ТОП-15 ключевых навыков в профессии {} '.format(keyword),
        xaxis_title="Ключевой навык",
        yaxis_title="Вакансий с навыком")
    fig.update_traces(textposition='outside')
    for trace, percent in zip(fig.data, lists_for_plots[keyword].head(15)['percent_of_vacancies']):
        trace.name = trace.name.split('=')[0] + ' (' + '{:.2%}'.format(percent) + ' вакансий)'


    fig.show()
# Out:
# <div>                            <div id="6a0b4408-4321-4d1e-8c3c-6692fa087903" class="plotly-graph-div" style="height:450px; width:950px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6a0b4408-4321-4d1e-8c3c-6692fa087903")) {                    Plotly.newPlot(                        "6a0b4408-4321-4d1e-8c3c-6692fa087903",                        [{"alignmentgroup":"True","hovertemplate":"skill=%{x}<br>vacancies=%{text}<extra></extra>","legendgroup":"sql","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"sql (69.43% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)","offsetgroup":"sql","orientation":"v","showlegend":true,"text":[134.0],"textposition":"outside","x":["sql"],"xaxis":"x","y":[134],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"skill=%{x}<br>vacancies=%{text}<extra></extra>","legendgroup":"python","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"python (54.92% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)","offsetgroup":"python","orientation":"v","showlegend":true,"text":[106.0],"textposition":"outside","x":["python"],"xaxis":"x","y":[106],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"skill=%{x}<br>vacancies=%{text}<extra></extra>","legendgroup":"\u0430\u043d\u0430\u043b\u0438\u0437 \u0434\u0430\u043d\u043d\u044b\u0445","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"\u0430\u043d\u0430\u043b\u0438\u0437 \u0434\u0430\u043d\u043d\u044b\u0445 (33.16% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)","offsetgroup":"\u0430\u043d\u0430\u043b\u0438\u0437 \u0434\u0430\u043d\u043d\u044b\u0445","orientation":"v","showlegend":true,"text":[64.0],"textposition":"outside","x":["\u0430\u043d\u0430\u043b\u0438\u0437 \u0434\u0430\u043d\u043d\u044b\u0445"],"xaxis":"x","y":[64],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"skill=%{x}<br>vacancies=%{text}<extra></extra>","legendgroup":"\u0430\u043d\u0430\u043b\u0438\u0442\u0438\u0447\u0435\u0441\u043a\u043e\u0435 \u043c\u044b\u0448\u043b\u0435\u043d\u0438\u0435","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"\u0430\u043d\u0430\u043b\u0438\u0442\u0438\u0447\u0435\u0441\u043a\u043e\u0435 \u043c\u044b\u0448\u043b\u0435\u043d\u0438\u0435 (22.28% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)","offsetgroup":"\u0430\u043d\u0430\u043b\u0438\u0442\u0438\u0447\u0435\u0441\u043a\u043e\u0435 \u043c\u044b\u0448\u043b\u0435\u043d\u0438\u0435","orientation":"v","showlegend":true,"text":[43.0],"textposition":"outside","x":["\u0430\u043d\u0430\u043b\u0438\u0442\u0438\u0447\u0435\u0441\u043a\u043e\u0435 \u043c\u044b\u0448\u043b\u0435\u043d\u0438\u0435"],"xaxis":"x","y":[43],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"skill=%{x}<br>vacancies=%{text}<extra></extra>","legendgroup":"power bi","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"power bi (20.73% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)","offsetgroup":"power bi","orientation":"v","showlegend":true,"text":[40.0],"textposition":"outside","x":["power bi"],"xaxis":"x","y":[40],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"skill=%{x}<br>vacancies=%{text}<extra></extra>","legendgroup":"ms excel","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"ms excel (19.69% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)","offsetgroup":"ms excel","orientation":"v","showlegend":true,"text":[38.0],"textposition":"outside","x":["ms excel"],"xaxis":"x","y":[38],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"skill=%{x}<br>vacancies=%{text}<extra></extra>","legendgroup":"\u0440\u0430\u0431\u043e\u0442\u0430 \u0441 \u0431\u043e\u043b\u044c\u0448\u0438\u043c \u043e\u0431\u044a\u0435\u043c\u043e\u043c \u0438\u043d\u0444\u043e\u0440\u043c\u0430\u0446\u0438\u0438","marker":{"color" ...
# <div>                            <div id="afbac3fe-c8a2-4b15-b25f-29bef4869c22" class="plotly-graph-div" style="height:450px; width:950px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("afbac3fe-c8a2-4b15-b25f-29bef4869c22")) {                    Plotly.newPlot(                        "afbac3fe-c8a2-4b15-b25f-29bef4869c22",                        [{"alignmentgroup":"True","hovertemplate":"skill=%{x}<br>vacancies=%{text}<extra></extra>","legendgroup":"\u0431\u0438\u0437\u043d\u0435\u0441 \u0430\u043d\u0430\u043b\u0438\u0437","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"\u0431\u0438\u0437\u043d\u0435\u0441 \u0430\u043d\u0430\u043b\u0438\u0437 (54.72% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)","offsetgroup":"\u0431\u0438\u0437\u043d\u0435\u0441 \u0430\u043d\u0430\u043b\u0438\u0437","orientation":"v","showlegend":true,"text":[278.0],"textposition":"outside","x":["\u0431\u0438\u0437\u043d\u0435\u0441 \u0430\u043d\u0430\u043b\u0438\u0437"],"xaxis":"x","y":[278],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"skill=%{x}<br>vacancies=%{text}<extra></extra>","legendgroup":"bpmn","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"bpmn (30.71% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)","offsetgroup":"bpmn","orientation":"v","showlegend":true,"text":[156.0],"textposition":"outside","x":["bpmn"],"xaxis":"x","y":[156],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"skill=%{x}<br>vacancies=%{text}<extra></extra>","legendgroup":"\u0430\u043d\u0430\u043b\u0438\u0442\u0438\u0447\u0435\u0441\u043a\u043e\u0435 \u043c\u044b\u0448\u043b\u0435\u043d\u0438\u0435","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"\u0430\u043d\u0430\u043b\u0438\u0442\u0438\u0447\u0435\u0441\u043a\u043e\u0435 \u043c\u044b\u0448\u043b\u0435\u043d\u0438\u0435 (21.85% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)","offsetgroup":"\u0430\u043d\u0430\u043b\u0438\u0442\u0438\u0447\u0435\u0441\u043a\u043e\u0435 \u043c\u044b\u0448\u043b\u0435\u043d\u0438\u0435","orientation":"v","showlegend":true,"text":[111.0],"textposition":"outside","x":["\u0430\u043d\u0430\u043b\u0438\u0442\u0438\u0447\u0435\u0441\u043a\u043e\u0435 \u043c\u044b\u0448\u043b\u0435\u043d\u0438\u0435"],"xaxis":"x","y":[111],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"skill=%{x}<br>vacancies=%{text}<extra></extra>","legendgroup":"\u043e\u043f\u0442\u0438\u043c\u0438\u0437\u0430\u0446\u0438\u044f \u0431\u0438\u0437\u043d\u0435\u0441 \u043f\u0440\u043e\u0446\u0435\u0441\u0441\u043e\u0432","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"\u043e\u043f\u0442\u0438\u043c\u0438\u0437\u0430\u0446\u0438\u044f \u0431\u0438\u0437\u043d\u0435\u0441 \u043f\u0440\u043e\u0446\u0435\u0441\u0441\u043e\u0432 (21.65% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)","offsetgroup":"\u043e\u043f\u0442\u0438\u043c\u0438\u0437\u0430\u0446\u0438\u044f \u0431\u0438\u0437\u043d\u0435\u0441 \u043f\u0440\u043e\u0446\u0435\u0441\u0441\u043e\u0432","orientation":"v","showlegend":true,"text":[110.0],"textposition":"outside","x":["\u043e\u043f\u0442\u0438\u043c\u0438\u0437\u0430\u0446\u0438\u044f \u0431\u0438\u0437\u043d\u0435\u0441 \u043f\u0440\u043e\u0446\u0435\u0441\u0441\u043e\u0432"],"xaxis":"x","y":[110],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"skill=%{x}<br>vacancies=%{text}<extra></extra>","legendgroup":"\u043c\u043e\u0434\u0435\u043b\u0438\u0440\u043e\u0432\u0430\u043d\u0438\u0435 \u0431\u0438\u0437\u043d\u0435\u0441 \u043f\u0440\u043e\u0446\u0435\u0441\u0441\u043e\u0432","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"\u043c\u043e\u0434\u0435\u043b\u0438\u0440\u043e\u0432\u0430\u043d\u0438\u0435 \u0431\u0438\u0437\u043d\u0435\u0441 \u043f\u0440\u043e\u0446\u0435\u0441\u0441\u043e\u0432 (20. ...
# <div>                            <div id="7a4ae4e8-7f47-422a-807d-d2f7870646c7" class="plotly-graph-div" style="height:450px; width:950px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7a4ae4e8-7f47-422a-807d-d2f7870646c7")) {                    Plotly.newPlot(                        "7a4ae4e8-7f47-422a-807d-d2f7870646c7",                        [{"alignmentgroup":"True","hovertemplate":"skill=%{x}<br>vacancies=%{text}<extra></extra>","legendgroup":"\u0431\u0438\u0437\u043d\u0435\u0441 \u0430\u043d\u0430\u043b\u0438\u0437","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"\u0431\u0438\u0437\u043d\u0435\u0441 \u0430\u043d\u0430\u043b\u0438\u0437 (41.23% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)","offsetgroup":"\u0431\u0438\u0437\u043d\u0435\u0441 \u0430\u043d\u0430\u043b\u0438\u0437","orientation":"v","showlegend":true,"text":[289.0],"textposition":"outside","x":["\u0431\u0438\u0437\u043d\u0435\u0441 \u0430\u043d\u0430\u043b\u0438\u0437"],"xaxis":"x","y":[289],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"skill=%{x}<br>vacancies=%{text}<extra></extra>","legendgroup":"sql","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"sql (32.81% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)","offsetgroup":"sql","orientation":"v","showlegend":true,"text":[230.0],"textposition":"outside","x":["sql"],"xaxis":"x","y":[230],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"skill=%{x}<br>vacancies=%{text}<extra></extra>","legendgroup":"bpmn","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"bpmn (22.82% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)","offsetgroup":"bpmn","orientation":"v","showlegend":true,"text":[160.0],"textposition":"outside","x":["bpmn"],"xaxis":"x","y":[160],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"skill=%{x}<br>vacancies=%{text}<extra></extra>","legendgroup":"\u0430\u043d\u0430\u043b\u0438\u0442\u0438\u0447\u0435\u0441\u043a\u043e\u0435 \u043c\u044b\u0448\u043b\u0435\u043d\u0438\u0435","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"\u0430\u043d\u0430\u043b\u0438\u0442\u0438\u0447\u0435\u0441\u043a\u043e\u0435 \u043c\u044b\u0448\u043b\u0435\u043d\u0438\u0435 (21.97% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)","offsetgroup":"\u0430\u043d\u0430\u043b\u0438\u0442\u0438\u0447\u0435\u0441\u043a\u043e\u0435 \u043c\u044b\u0448\u043b\u0435\u043d\u0438\u0435","orientation":"v","showlegend":true,"text":[154.0],"textposition":"outside","x":["\u0430\u043d\u0430\u043b\u0438\u0442\u0438\u0447\u0435\u0441\u043a\u043e\u0435 \u043c\u044b\u0448\u043b\u0435\u043d\u0438\u0435"],"xaxis":"x","y":[154],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"skill=%{x}<br>vacancies=%{text}<extra></extra>","legendgroup":"python","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"python (16.69% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)","offsetgroup":"python","orientation":"v","showlegend":true,"text":[117.0],"textposition":"outside","x":["python"],"xaxis":"x","y":[117],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"skill=%{x}<br>vacancies=%{text}<extra></extra>","legendgroup":"\u0430\u043d\u0430\u043b\u0438\u0437 \u0434\u0430\u043d\u043d\u044b\u0445","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"\u0430\u043d\u0430\u043b\u0438\u0437 \u0434\u0430\u043d\u043d\u044b\u0445 (16.55% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)","offsetgroup":"\u0430\u043d\u0430\u043b\u0438\u0437 \u0434\u0430\u043d\u043d\u044b\u0445","orientation":"v","showlegend":true,"text":[116.0],"textposition":"outside","x":["\u0430\u043d\u0430\u043b\u0438\u0437 \u0434\u0430\u043d\u043d\u044b\u0445"],"xaxis":"x","y":[116],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"skill=%{x}<br>vacanc ...

# %% [markdown]
# ## ТОП 15 ключевых навыков у Аналитика данных и Бизнес аналитика в разрезе требуемого опыта

# %%
df['skills_list'] = df['key_skills_from_key_skills_field'].apply(lambda x: x.split(', '))
df

skills_list = []
skills_junior_1_3_y = []
skills_middle_3_6_y = []
skills_junior_no_exp = []
skills_senior = []
lists = {
    'junior+ (1-3 years)':skills_junior_1_3_y,
    'middle (3-6 years)':skills_middle_3_6_y,
    'junior (no experince)':skills_junior_no_exp,
    'senior (6+ years)':skills_senior

}


for keyword in lists:
    for skills in df.query('experience==@keyword and category=="аналитик данных"')['skills_list']:
        for skill in skills:
            if skill!='неизвестно':
                lists[keyword].append(skill)

skills_list = skills_junior_1_3_y + skills_middle_3_6_y + skills_junior_no_exp + skills_senior
  

skills_junior_1_3_y_df = pd.DataFrame({'skill':skills_junior_1_3_y})
skills_middle_3_6_y_df = pd.DataFrame({'skill':skills_middle_3_6_y})
skills_junior_no_exp_df = pd.DataFrame({'skill':skills_junior_no_exp})
skills_senior_df = pd.DataFrame({'skill':skills_senior})
skills = pd.DataFrame({'skill':skills_list})

skills_junior_1_3_y_df = pd.DataFrame(skills_junior_1_3_y_df['skill'].value_counts()).reset_index()
skills_middle_3_6_y_df = pd.DataFrame(skills_middle_3_6_y_df['skill'].value_counts()).reset_index()
skills_junior_no_exp_df = pd.DataFrame(skills_junior_no_exp_df['skill'].value_counts()).reset_index()
skills_senior_df = pd.DataFrame(skills_senior_df['skill'].value_counts()).reset_index()
skills = pd.DataFrame(skills['skill'].value_counts()).reset_index()

skills_junior_1_3_y_df.columns = ['skill', 'vacancies']
skills_middle_3_6_y_df.columns = ['skill', 'vacancies']
skills_junior_no_exp_df.columns = ['skill', 'vacancies']
skills_senior_df.columns = ['skill', 'vacancies']
skills.columns = ['skill', 'vacancies']

skills_junior_1_3_y_df['percent_of_vacancies'] = skills_junior_1_3_y_df['vacancies'] / len(df.query('key_skills_from_key_skills_field != "неизвестно" and experience == "junior+ (1-3 years)"'))
skills_middle_3_6_y_df['percent_of_vacancies'] = skills_middle_3_6_y_df['vacancies'] / len(df.query('key_skills_from_key_skills_field != "неизвестно" and experience=="middle (3-6 years)"'))       
skills_junior_no_exp_df['percent_of_vacancies'] = skills_junior_no_exp_df['vacancies'] / len(df.query('key_skills_from_key_skills_field != "неизвестно" and experience=="junior (no experince)"'))
skills_senior_df['percent_of_vacancies'] = skills_senior_df['vacancies'] / len(df.query('key_skills_from_key_skills_field != "неизвестно" and experience=="senior (6+ years)"'))
skills['percent_of_vacancies'] = skills['vacancies'] / len(df.query('key_skills_from_key_skills_field != "неизвестно"'))


lists_for_plots = {
    'junior+ (1-3 years)':skills_junior_1_3_y_df,
    'middle (3-6 years)':skills_middle_3_6_y_df, 
    'junior (no experince)':skills_junior_no_exp_df,
    'senior (6+ years)':skills_senior_df
}
for keyword in lists_for_plots:
    fig = px.bar(lists_for_plots[keyword].head(15), x='skill', y='vacancies', width = 950, height = 450, color='skill', text='vacancies')
    fig.update_xaxes(tickangle=30)
    fig.update_layout(
        title='ТОП-15 ключевых навыков в профессии аналитик данных у {} '.format(keyword),
        xaxis_title="Ключевые навыки",
        yaxis_title="Количество вакансий с данным навыком")
    fig.update_traces(textposition='outside')
    for trace, percent in zip(fig.data, lists_for_plots[keyword].head(15)['percent_of_vacancies']):
        trace.name = trace.name.split('=')[0] + ' (' + '{:.2%}'.format(percent) + ' вакансий)'


    fig.show()
# Out:
# <div>                            <div id="57af88be-d5bd-4c18-bbac-33c4ec6b11f8" class="plotly-graph-div" style="height:450px; width:950px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("57af88be-d5bd-4c18-bbac-33c4ec6b11f8")) {                    Plotly.newPlot(                        "57af88be-d5bd-4c18-bbac-33c4ec6b11f8",                        [{"alignmentgroup":"True","hovertemplate":"skill=%{x}<br>vacancies=%{text}<extra></extra>","legendgroup":"sql","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"sql (19.61% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)","offsetgroup":"sql","orientation":"v","showlegend":true,"text":[70.0],"textposition":"outside","x":["sql"],"xaxis":"x","y":[70],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"skill=%{x}<br>vacancies=%{text}<extra></extra>","legendgroup":"python","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"python (14.01% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)","offsetgroup":"python","orientation":"v","showlegend":true,"text":[50.0],"textposition":"outside","x":["python"],"xaxis":"x","y":[50],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"skill=%{x}<br>vacancies=%{text}<extra></extra>","legendgroup":"\u0430\u043d\u0430\u043b\u0438\u0437 \u0434\u0430\u043d\u043d\u044b\u0445","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"\u0430\u043d\u0430\u043b\u0438\u0437 \u0434\u0430\u043d\u043d\u044b\u0445 (12.04% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)","offsetgroup":"\u0430\u043d\u0430\u043b\u0438\u0437 \u0434\u0430\u043d\u043d\u044b\u0445","orientation":"v","showlegend":true,"text":[43.0],"textposition":"outside","x":["\u0430\u043d\u0430\u043b\u0438\u0437 \u0434\u0430\u043d\u043d\u044b\u0445"],"xaxis":"x","y":[43],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"skill=%{x}<br>vacancies=%{text}<extra></extra>","legendgroup":"\u0430\u043d\u0430\u043b\u0438\u0442\u0438\u0447\u0435\u0441\u043a\u043e\u0435 \u043c\u044b\u0448\u043b\u0435\u043d\u0438\u0435","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"\u0430\u043d\u0430\u043b\u0438\u0442\u0438\u0447\u0435\u0441\u043a\u043e\u0435 \u043c\u044b\u0448\u043b\u0435\u043d\u0438\u0435 (7.56% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)","offsetgroup":"\u0430\u043d\u0430\u043b\u0438\u0442\u0438\u0447\u0435\u0441\u043a\u043e\u0435 \u043c\u044b\u0448\u043b\u0435\u043d\u0438\u0435","orientation":"v","showlegend":true,"text":[27.0],"textposition":"outside","x":["\u0430\u043d\u0430\u043b\u0438\u0442\u0438\u0447\u0435\u0441\u043a\u043e\u0435 \u043c\u044b\u0448\u043b\u0435\u043d\u0438\u0435"],"xaxis":"x","y":[27],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"skill=%{x}<br>vacancies=%{text}<extra></extra>","legendgroup":"ms excel","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"ms excel (7.56% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)","offsetgroup":"ms excel","orientation":"v","showlegend":true,"text":[27.0],"textposition":"outside","x":["ms excel"],"xaxis":"x","y":[27],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"skill=%{x}<br>vacancies=%{text}<extra></extra>","legendgroup":"\u0440\u0430\u0431\u043e\u0442\u0430 \u0441 \u0431\u043e\u043b\u044c\u0448\u0438\u043c \u043e\u0431\u044a\u0435\u043c\u043e\u043c \u0438\u043d\u0444\u043e\u0440\u043c\u0430\u0446\u0438\u0438","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"\u0440\u0430\u0431\u043e\u0442\u0430 \u0441 \u0431\u043e\u043b\u044c\u0448\u0438\u043c \u043e\u0431\u044a\u0435\u043c\u043e\u043c \u0438\u043d\u0444\u043e\u0440\u043c\u0430\u0446\u0438\u0438 (6.72% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)","offsetgroup":"\u0440\u0430\u0431\u043e\u0442\u0430 \u0441 \u0431\u043e\u043b\u044c\u0448\u0438\u043c \u043e\u0431\u044a\ ...
# <div>                            <div id="726f0570-3220-458f-9262-50fe086c3750" class="plotly-graph-div" style="height:450px; width:950px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("726f0570-3220-458f-9262-50fe086c3750")) {                    Plotly.newPlot(                        "726f0570-3220-458f-9262-50fe086c3750",                        [{"alignmentgroup":"True","hovertemplate":"skill=%{x}<br>vacancies=%{text}<extra></extra>","legendgroup":"sql","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"sql (19.24% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)","offsetgroup":"sql","orientation":"v","showlegend":true,"text":[56.0],"textposition":"outside","x":["sql"],"xaxis":"x","y":[56],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"skill=%{x}<br>vacancies=%{text}<extra></extra>","legendgroup":"python","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"python (17.18% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)","offsetgroup":"python","orientation":"v","showlegend":true,"text":[50.0],"textposition":"outside","x":["python"],"xaxis":"x","y":[50],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"skill=%{x}<br>vacancies=%{text}<extra></extra>","legendgroup":"\u0430\u043d\u0430\u043b\u0438\u0437 \u0434\u0430\u043d\u043d\u044b\u0445","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"\u0430\u043d\u0430\u043b\u0438\u0437 \u0434\u0430\u043d\u043d\u044b\u0445 (6.53% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)","offsetgroup":"\u0430\u043d\u0430\u043b\u0438\u0437 \u0434\u0430\u043d\u043d\u044b\u0445","orientation":"v","showlegend":true,"text":[19.0],"textposition":"outside","x":["\u0430\u043d\u0430\u043b\u0438\u0437 \u0434\u0430\u043d\u043d\u044b\u0445"],"xaxis":"x","y":[19],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"skill=%{x}<br>vacancies=%{text}<extra></extra>","legendgroup":"power bi","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"power bi (5.84% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)","offsetgroup":"power bi","orientation":"v","showlegend":true,"text":[17.0],"textposition":"outside","x":["power bi"],"xaxis":"x","y":[17],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"skill=%{x}<br>vacancies=%{text}<extra></extra>","legendgroup":"\u0430\u043d\u0430\u043b\u0438\u0442\u0438\u0447\u0435\u0441\u043a\u043e\u0435 \u043c\u044b\u0448\u043b\u0435\u043d\u0438\u0435","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"\u0430\u043d\u0430\u043b\u0438\u0442\u0438\u0447\u0435\u0441\u043a\u043e\u0435 \u043c\u044b\u0448\u043b\u0435\u043d\u0438\u0435 (4.12% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)","offsetgroup":"\u0430\u043d\u0430\u043b\u0438\u0442\u0438\u0447\u0435\u0441\u043a\u043e\u0435 \u043c\u044b\u0448\u043b\u0435\u043d\u0438\u0435","orientation":"v","showlegend":true,"text":[12.0],"textposition":"outside","x":["\u0430\u043d\u0430\u043b\u0438\u0442\u0438\u0447\u0435\u0441\u043a\u043e\u0435 \u043c\u044b\u0448\u043b\u0435\u043d\u0438\u0435"],"xaxis":"x","y":[12],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"skill=%{x}<br>vacancies=%{text}<extra></extra>","legendgroup":"\u0431\u0430\u0437\u044b \u0434\u0430\u043d\u043d\u044b\u0445","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"\u0431\u0430\u0437\u044b \u0434\u0430\u043d\u043d\u044b\u0445 (3.78% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)","offsetgroup":"\u0431\u0430\u0437\u044b \u0434\u0430\u043d\u043d\u044b\u0445","orientation":"v","showlegend":true,"text":[11.0],"textposition":"outside","x":["\u0431\u0430\u0437\u044b \u0434\u0430\u043d\u043d\u044b\u0445"],"xaxis":"x","y":[11],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"skill=%{x}<br>vacancies=%{text}<extra></extra>","legendgroup":"\u043 ...
# <div>                            <div id="db868f99-2e4e-4ab5-94d6-2cc92d0f119d" class="plotly-graph-div" style="height:450px; width:950px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("db868f99-2e4e-4ab5-94d6-2cc92d0f119d")) {                    Plotly.newPlot(                        "db868f99-2e4e-4ab5-94d6-2cc92d0f119d",                        [{"alignmentgroup":"True","hovertemplate":"skill=%{x}<br>vacancies=%{text}<extra></extra>","legendgroup":"sql","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"sql (16.33% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)","offsetgroup":"sql","orientation":"v","showlegend":true,"text":[8.0],"textposition":"outside","x":["sql"],"xaxis":"x","y":[8],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"skill=%{x}<br>vacancies=%{text}<extra></extra>","legendgroup":"ms excel","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"ms excel (14.29% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)","offsetgroup":"ms excel","orientation":"v","showlegend":true,"text":[7.0],"textposition":"outside","x":["ms excel"],"xaxis":"x","y":[7],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"skill=%{x}<br>vacancies=%{text}<extra></extra>","legendgroup":"python","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"python (12.24% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)","offsetgroup":"python","orientation":"v","showlegend":true,"text":[6.0],"textposition":"outside","x":["python"],"xaxis":"x","y":[6],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"skill=%{x}<br>vacancies=%{text}<extra></extra>","legendgroup":"ms powerpoint","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"ms powerpoint (8.16% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)","offsetgroup":"ms powerpoint","orientation":"v","showlegend":true,"text":[4.0],"textposition":"outside","x":["ms powerpoint"],"xaxis":"x","y":[4],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"skill=%{x}<br>vacancies=%{text}<extra></extra>","legendgroup":"\u0430\u043d\u0430\u043b\u0438\u0442\u0438\u0447\u0435\u0441\u043a\u043e\u0435 \u043c\u044b\u0448\u043b\u0435\u043d\u0438\u0435","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"\u0430\u043d\u0430\u043b\u0438\u0442\u0438\u0447\u0435\u0441\u043a\u043e\u0435 \u043c\u044b\u0448\u043b\u0435\u043d\u0438\u0435 (8.16% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)","offsetgroup":"\u0430\u043d\u0430\u043b\u0438\u0442\u0438\u0447\u0435\u0441\u043a\u043e\u0435 \u043c\u044b\u0448\u043b\u0435\u043d\u0438\u0435","orientation":"v","showlegend":true,"text":[4.0],"textposition":"outside","x":["\u0430\u043d\u0430\u043b\u0438\u0442\u0438\u0447\u0435\u0441\u043a\u043e\u0435 \u043c\u044b\u0448\u043b\u0435\u043d\u0438\u0435"],"xaxis":"x","y":[4],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"skill=%{x}<br>vacancies=%{text}<extra></extra>","legendgroup":"\u0440\u0430\u0431\u043e\u0442\u0430 \u0441 \u0431\u043e\u043b\u044c\u0448\u0438\u043c \u043e\u0431\u044a\u0435\u043c\u043e\u043c \u0438\u043d\u0444\u043e\u0440\u043c\u0430\u0446\u0438\u0438","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"\u0440\u0430\u0431\u043e\u0442\u0430 \u0441 \u0431\u043e\u043b\u044c\u0448\u0438\u043c \u043e\u0431\u044a\u0435\u043c\u043e\u043c \u0438\u043d\u0444\u043e\u0440\u043c\u0430\u0446\u0438\u0438 (8.16% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)","offsetgroup":"\u0440\u0430\u0431\u043e\u0442\u0430 \u0441 \u0431\u043e\u043b\u044c\u0448\u0438\u043c \u043e\u0431\u044a\u0435\u043c\u043e\u043c \u0438\u043d\u0444\u043e\u0440\u043c\u0430\u0446\u0438\u0438","orientation":"v","showlegend":true,"text":[4.0],"textposition":"outside","x":["\u0440\u0430\u0431\u043e\u0442\u0430 \u0441 \u0431\u043e\u043b\u044c\u0448\u0438\u04 ...
# <div>                            <div id="72abbe9a-290e-4028-8b25-8b6c63d5feb5" class="plotly-graph-div" style="height:450px; width:950px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("72abbe9a-290e-4028-8b25-8b6c63d5feb5")) {                    Plotly.newPlot(                        "72abbe9a-290e-4028-8b25-8b6c63d5feb5",                        [{"alignmentgroup":"True","hovertemplate":"skill=%{marker.color}<br>vacancies=%{text}<extra></extra>","legendgroup":"","marker":{"color":[],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"text":[],"textposition":"outside","x":[],"xaxis":"x","y":[],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{ ...

# %%
df['skills_list'] = df['key_skills_from_key_skills_field'].apply(lambda x: x.split(', '))
df

skills_list = []
skills_junior_1_3_y = []
skills_middle_3_6_y = []
skills_junior_no_exp = []
skills_senior = []
lists = {
    'junior+ (1-3 years)':skills_junior_1_3_y,
    'middle (3-6 years)':skills_middle_3_6_y,
    'junior (no experince)':skills_junior_no_exp,
    'senior (6+ years)':skills_senior

}


for keyword in lists:
    for skills in df.query('experience==@keyword and category=="бизнес аналитик"')['skills_list']:
        for skill in skills:
            if skill!='неизвестно':
                lists[keyword].append(skill)

skills_list = skills_junior_1_3_y + skills_middle_3_6_y + skills_junior_no_exp + skills_senior
  

skills_junior_1_3_y_df = pd.DataFrame({'skill':skills_junior_1_3_y})
skills_middle_3_6_y_df = pd.DataFrame({'skill':skills_middle_3_6_y})
skills_junior_no_exp_df = pd.DataFrame({'skill':skills_junior_no_exp})
skills_senior_df = pd.DataFrame({'skill':skills_senior})
skills = pd.DataFrame({'skill':skills_list})

skills_junior_1_3_y_df = pd.DataFrame(skills_junior_1_3_y_df['skill'].value_counts()).reset_index()
skills_middle_3_6_y_df = pd.DataFrame(skills_middle_3_6_y_df['skill'].value_counts()).reset_index()
skills_junior_no_exp_df = pd.DataFrame(skills_junior_no_exp_df['skill'].value_counts()).reset_index()
skills_senior_df = pd.DataFrame(skills_senior_df['skill'].value_counts()).reset_index()
skills = pd.DataFrame(skills['skill'].value_counts()).reset_index()

skills_junior_1_3_y_df.columns = ['skill', 'vacancies']
skills_middle_3_6_y_df.columns = ['skill', 'vacancies']
skills_junior_no_exp_df.columns = ['skill', 'vacancies']
skills_senior_df.columns = ['skill', 'vacancies']
skills.columns = ['skill', 'vacancies']

skills_junior_1_3_y_df['percent_of_vacancies'] = skills_junior_1_3_y_df['vacancies'] / len(df.query('key_skills_from_key_skills_field != "неизвестно" and experience == "junior+ (1-3 years)"'))
skills_middle_3_6_y_df['percent_of_vacancies'] = skills_middle_3_6_y_df['vacancies'] / len(df.query('key_skills_from_key_skills_field != "неизвестно" and experience=="middle (3-6 years)"'))       
skills_junior_no_exp_df['percent_of_vacancies'] = skills_junior_no_exp_df['vacancies'] / len(df.query('key_skills_from_key_skills_field != "неизвестно" and experience=="junior (no experince)"'))
skills_senior_df['percent_of_vacancies'] = skills_senior_df['vacancies'] / len(df.query('key_skills_from_key_skills_field != "неизвестно" and experience=="senior (6+ years)"'))
skills['percent_of_vacancies'] = skills['vacancies'] / len(df.query('key_skills_from_key_skills_field != "неизвестно"'))


lists_for_plots = {
    'junior+ (1-3 years)':skills_junior_1_3_y_df,
    'middle (3-6 years)':skills_middle_3_6_y_df, 
    'junior (no experince)':skills_junior_no_exp_df,
    'senior (6+ years)':skills_senior_df
}
for keyword in lists_for_plots:
    fig = px.bar(lists_for_plots[keyword].head(15), x='skill', y='vacancies', width = 950, height = 450, color='skill', text='vacancies')
    fig.update_xaxes(tickangle=30)
    fig.update_layout(
        title='ТОП-15 ключевых навыков в профессии бизнес аналитик у {} '.format(keyword),
        xaxis_title="Ключевые навыки",
        yaxis_title="Количество вакансий с данным навыком")
    fig.update_traces(textposition='outside')
    for trace, percent in zip(fig.data, lists_for_plots[keyword].head(15)['percent_of_vacancies']):
        trace.name = trace.name.split('=')[0] + ' (' + '{:.2%}'.format(percent) + ' вакансий)'


    fig.show()
# Out:
# <div>                            <div id="ea3bed2e-89a9-4121-8d6f-7bc12d1c106e" class="plotly-graph-div" style="height:450px; width:950px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ea3bed2e-89a9-4121-8d6f-7bc12d1c106e")) {                    Plotly.newPlot(                        "ea3bed2e-89a9-4121-8d6f-7bc12d1c106e",                        [{"alignmentgroup":"True","hovertemplate":"skill=%{x}<br>vacancies=%{text}<extra></extra>","legendgroup":"\u0431\u0438\u0437\u043d\u0435\u0441 \u0430\u043d\u0430\u043b\u0438\u0437","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"\u0431\u0438\u0437\u043d\u0435\u0441 \u0430\u043d\u0430\u043b\u0438\u0437 (37.82% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)","offsetgroup":"\u0431\u0438\u0437\u043d\u0435\u0441 \u0430\u043d\u0430\u043b\u0438\u0437","orientation":"v","showlegend":true,"text":[135.0],"textposition":"outside","x":["\u0431\u0438\u0437\u043d\u0435\u0441 \u0430\u043d\u0430\u043b\u0438\u0437"],"xaxis":"x","y":[135],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"skill=%{x}<br>vacancies=%{text}<extra></extra>","legendgroup":"bpmn","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"bpmn (21.57% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)","offsetgroup":"bpmn","orientation":"v","showlegend":true,"text":[77.0],"textposition":"outside","x":["bpmn"],"xaxis":"x","y":[77],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"skill=%{x}<br>vacancies=%{text}<extra></extra>","legendgroup":"\u043e\u043f\u0442\u0438\u043c\u0438\u0437\u0430\u0446\u0438\u044f \u0431\u0438\u0437\u043d\u0435\u0441 \u043f\u0440\u043e\u0446\u0435\u0441\u0441\u043e\u0432","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"\u043e\u043f\u0442\u0438\u043c\u0438\u0437\u0430\u0446\u0438\u044f \u0431\u0438\u0437\u043d\u0435\u0441 \u043f\u0440\u043e\u0446\u0435\u0441\u0441\u043e\u0432 (18.49% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)","offsetgroup":"\u043e\u043f\u0442\u0438\u043c\u0438\u0437\u0430\u0446\u0438\u044f \u0431\u0438\u0437\u043d\u0435\u0441 \u043f\u0440\u043e\u0446\u0435\u0441\u0441\u043e\u0432","orientation":"v","showlegend":true,"text":[66.0],"textposition":"outside","x":["\u043e\u043f\u0442\u0438\u043c\u0438\u0437\u0430\u0446\u0438\u044f \u0431\u0438\u0437\u043d\u0435\u0441 \u043f\u0440\u043e\u0446\u0435\u0441\u0441\u043e\u0432"],"xaxis":"x","y":[66],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"skill=%{x}<br>vacancies=%{text}<extra></extra>","legendgroup":"\u0430\u043d\u0430\u043b\u0438\u0442\u0438\u0447\u0435\u0441\u043a\u043e\u0435 \u043c\u044b\u0448\u043b\u0435\u043d\u0438\u0435","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"\u0430\u043d\u0430\u043b\u0438\u0442\u0438\u0447\u0435\u0441\u043a\u043e\u0435 \u043c\u044b\u0448\u043b\u0435\u043d\u0438\u0435 (17.65% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)","offsetgroup":"\u0430\u043d\u0430\u043b\u0438\u0442\u0438\u0447\u0435\u0441\u043a\u043e\u0435 \u043c\u044b\u0448\u043b\u0435\u043d\u0438\u0435","orientation":"v","showlegend":true,"text":[63.0],"textposition":"outside","x":["\u0430\u043d\u0430\u043b\u0438\u0442\u0438\u0447\u0435\u0441\u043a\u043e\u0435 \u043c\u044b\u0448\u043b\u0435\u043d\u0438\u0435"],"xaxis":"x","y":[63],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"skill=%{x}<br>vacancies=%{text}<extra></extra>","legendgroup":"sql","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"sql (14.01% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)","offsetgroup":"sql","orientation":"v","showlegend":true,"text":[50.0],"textposition":"outside","x":["sql"],"xaxis":"x","y":[50],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"skill=%{x}<br>vacancies=%{text}<extra></extra>","legendgroup":"\u043c\u043e\u0434\u0435\u ...
# <div>                            <div id="b2a77066-0c27-4bea-9cc1-59735a408666" class="plotly-graph-div" style="height:450px; width:950px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b2a77066-0c27-4bea-9cc1-59735a408666")) {                    Plotly.newPlot(                        "b2a77066-0c27-4bea-9cc1-59735a408666",                        [{"alignmentgroup":"True","hovertemplate":"skill=%{x}<br>vacancies=%{text}<extra></extra>","legendgroup":"\u0431\u0438\u0437\u043d\u0435\u0441 \u0430\u043d\u0430\u043b\u0438\u0437","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"\u0431\u0438\u0437\u043d\u0435\u0441 \u0430\u043d\u0430\u043b\u0438\u0437 (41.58% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)","offsetgroup":"\u0431\u0438\u0437\u043d\u0435\u0441 \u0430\u043d\u0430\u043b\u0438\u0437","orientation":"v","showlegend":true,"text":[121.0],"textposition":"outside","x":["\u0431\u0438\u0437\u043d\u0435\u0441 \u0430\u043d\u0430\u043b\u0438\u0437"],"xaxis":"x","y":[121],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"skill=%{x}<br>vacancies=%{text}<extra></extra>","legendgroup":"bpmn","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"bpmn (23.37% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)","offsetgroup":"bpmn","orientation":"v","showlegend":true,"text":[68.0],"textposition":"outside","x":["bpmn"],"xaxis":"x","y":[68],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"skill=%{x}<br>vacancies=%{text}<extra></extra>","legendgroup":"\u043c\u043e\u0434\u0435\u043b\u0438\u0440\u043e\u0432\u0430\u043d\u0438\u0435 \u0431\u0438\u0437\u043d\u0435\u0441 \u043f\u0440\u043e\u0446\u0435\u0441\u0441\u043e\u0432","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"\u043c\u043e\u0434\u0435\u043b\u0438\u0440\u043e\u0432\u0430\u043d\u0438\u0435 \u0431\u0438\u0437\u043d\u0435\u0441 \u043f\u0440\u043e\u0446\u0435\u0441\u0441\u043e\u0432 (16.84% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)","offsetgroup":"\u043c\u043e\u0434\u0435\u043b\u0438\u0440\u043e\u0432\u0430\u043d\u0438\u0435 \u0431\u0438\u0437\u043d\u0435\u0441 \u043f\u0440\u043e\u0446\u0435\u0441\u0441\u043e\u0432","orientation":"v","showlegend":true,"text":[49.0],"textposition":"outside","x":["\u043c\u043e\u0434\u0435\u043b\u0438\u0440\u043e\u0432\u0430\u043d\u0438\u0435 \u0431\u0438\u0437\u043d\u0435\u0441 \u043f\u0440\u043e\u0446\u0435\u0441\u0441\u043e\u0432"],"xaxis":"x","y":[49],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"skill=%{x}<br>vacancies=%{text}<extra></extra>","legendgroup":"\u043e\u043f\u0442\u0438\u043c\u0438\u0437\u0430\u0446\u0438\u044f \u0431\u0438\u0437\u043d\u0435\u0441 \u043f\u0440\u043e\u0446\u0435\u0441\u0441\u043e\u0432","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"\u043e\u043f\u0442\u0438\u043c\u0438\u0437\u0430\u0446\u0438\u044f \u0431\u0438\u0437\u043d\u0435\u0441 \u043f\u0440\u043e\u0446\u0435\u0441\u0441\u043e\u0432 (13.75% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)","offsetgroup":"\u043e\u043f\u0442\u0438\u043c\u0438\u0437\u0430\u0446\u0438\u044f \u0431\u0438\u0437\u043d\u0435\u0441 \u043f\u0440\u043e\u0446\u0435\u0441\u0441\u043e\u0432","orientation":"v","showlegend":true,"text":[40.0],"textposition":"outside","x":["\u043e\u043f\u0442\u0438\u043c\u0438\u0437\u0430\u0446\u0438\u044f \u0431\u0438\u0437\u043d\u0435\u0441 \u043f\u0440\u043e\u0446\u0435\u0441\u0441\u043e\u0432"],"xaxis":"x","y":[40],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"skill=%{x}<br>vacancies=%{text}<extra></extra>","legendgroup":"\u0430\u043d\u0430\u043b\u0438\u0442\u0438\u0447\u0435\u0441\u043a\u043e\u0435 \u043c\u044b\u0448\u043b\u0435\u043d\u0438\u0435","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"\u0430\u043d\u0430\u043b\u0438\u0442\u0438\u0447\u04 ...
# <div>                            <div id="a7d71de9-d706-4aa3-9d58-2761a0020e68" class="plotly-graph-div" style="height:450px; width:950px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a7d71de9-d706-4aa3-9d58-2761a0020e68")) {                    Plotly.newPlot(                        "a7d71de9-d706-4aa3-9d58-2761a0020e68",                        [{"alignmentgroup":"True","hovertemplate":"skill=%{x}<br>vacancies=%{text}<extra></extra>","legendgroup":"\u0431\u0438\u0437\u043d\u0435\u0441 \u0430\u043d\u0430\u043b\u0438\u0437","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"\u0431\u0438\u0437\u043d\u0435\u0441 \u0430\u043d\u0430\u043b\u0438\u0437 (38.78% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)","offsetgroup":"\u0431\u0438\u0437\u043d\u0435\u0441 \u0430\u043d\u0430\u043b\u0438\u0437","orientation":"v","showlegend":true,"text":[19.0],"textposition":"outside","x":["\u0431\u0438\u0437\u043d\u0435\u0441 \u0430\u043d\u0430\u043b\u0438\u0437"],"xaxis":"x","y":[19],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"skill=%{x}<br>vacancies=%{text}<extra></extra>","legendgroup":"\u043c\u043e\u0434\u0435\u043b\u0438\u0440\u043e\u0432\u0430\u043d\u0438\u0435 \u0431\u0438\u0437\u043d\u0435\u0441 \u043f\u0440\u043e\u0446\u0435\u0441\u0441\u043e\u0432","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"\u043c\u043e\u0434\u0435\u043b\u0438\u0440\u043e\u0432\u0430\u043d\u0438\u0435 \u0431\u0438\u0437\u043d\u0435\u0441 \u043f\u0440\u043e\u0446\u0435\u0441\u0441\u043e\u0432 (28.57% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)","offsetgroup":"\u043c\u043e\u0434\u0435\u043b\u0438\u0440\u043e\u0432\u0430\u043d\u0438\u0435 \u0431\u0438\u0437\u043d\u0435\u0441 \u043f\u0440\u043e\u0446\u0435\u0441\u0441\u043e\u0432","orientation":"v","showlegend":true,"text":[14.0],"textposition":"outside","x":["\u043c\u043e\u0434\u0435\u043b\u0438\u0440\u043e\u0432\u0430\u043d\u0438\u0435 \u0431\u0438\u0437\u043d\u0435\u0441 \u043f\u0440\u043e\u0446\u0435\u0441\u0441\u043e\u0432"],"xaxis":"x","y":[14],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"skill=%{x}<br>vacancies=%{text}<extra></extra>","legendgroup":"sql","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"sql (22.45% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)","offsetgroup":"sql","orientation":"v","showlegend":true,"text":[11.0],"textposition":"outside","x":["sql"],"xaxis":"x","y":[11],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"skill=%{x}<br>vacancies=%{text}<extra></extra>","legendgroup":"\u0430\u043d\u0430\u043b\u0438\u0442\u0438\u0447\u0435\u0441\u043a\u0438\u0439 \u0441\u043a\u043b\u0430\u0434 \u0443\u043c\u0430","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"\u0430\u043d\u0430\u043b\u0438\u0442\u0438\u0447\u0435\u0441\u043a\u0438\u0439 \u0441\u043a\u043b\u0430\u0434 \u0443\u043c\u0430 (18.37% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)","offsetgroup":"\u0430\u043d\u0430\u043b\u0438\u0442\u0438\u0447\u0435\u0441\u043a\u0438\u0439 \u0441\u043a\u043b\u0430\u0434 \u0443\u043c\u0430","orientation":"v","showlegend":true,"text":[9.0],"textposition":"outside","x":["\u0430\u043d\u0430\u043b\u0438\u0442\u0438\u0447\u0435\u0441\u043a\u0438\u0439 \u0441\u043a\u043b\u0430\u0434 \u0443\u043c\u0430"],"xaxis":"x","y":[9],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"skill=%{x}<br>vacancies=%{text}<extra></extra>","legendgroup":"bpmn","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"bpmn (18.37% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)","offsetgroup":"bpmn","orientation":"v","showlegend":true,"text":[9.0],"textposition":"outside","x":["bpmn"],"xaxis":"x","y":[9],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"skill=%{x}<br>vacancies=%{text}<extra></ext ...
# <div>                            <div id="c9b83d85-6590-4e26-8d7f-ac49b7c4a564" class="plotly-graph-div" style="height:450px; width:950px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c9b83d85-6590-4e26-8d7f-ac49b7c4a564")) {                    Plotly.newPlot(                        "c9b83d85-6590-4e26-8d7f-ac49b7c4a564",                        [{"alignmentgroup":"True","hovertemplate":"skill=%{x}<br>vacancies=%{text}<extra></extra>","legendgroup":"\u0431\u0438\u0437\u043d\u0435\u0441 \u0430\u043d\u0430\u043b\u0438\u0437","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"\u0431\u0438\u0437\u043d\u0435\u0441 \u0430\u043d\u0430\u043b\u0438\u0437 (75.00% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)","offsetgroup":"\u0431\u0438\u0437\u043d\u0435\u0441 \u0430\u043d\u0430\u043b\u0438\u0437","orientation":"v","showlegend":true,"text":[3.0],"textposition":"outside","x":["\u0431\u0438\u0437\u043d\u0435\u0441 \u0430\u043d\u0430\u043b\u0438\u0437"],"xaxis":"x","y":[3],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"skill=%{x}<br>vacancies=%{text}<extra></extra>","legendgroup":"bpmn","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"bpmn (50.00% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)","offsetgroup":"bpmn","orientation":"v","showlegend":true,"text":[2.0],"textposition":"outside","x":["bpmn"],"xaxis":"x","y":[2],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"skill=%{x}<br>vacancies=%{text}<extra></extra>","legendgroup":"sql","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"sql (50.00% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)","offsetgroup":"sql","orientation":"v","showlegend":true,"text":[2.0],"textposition":"outside","x":["sql"],"xaxis":"x","y":[2],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"skill=%{x}<br>vacancies=%{text}<extra></extra>","legendgroup":"ms excel","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"ms excel (25.00% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)","offsetgroup":"ms excel","orientation":"v","showlegend":true,"text":[1.0],"textposition":"outside","x":["ms excel"],"xaxis":"x","y":[1],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"skill=%{x}<br>vacancies=%{text}<extra></extra>","legendgroup":"start up project","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"start up project (25.00% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)","offsetgroup":"start up project","orientation":"v","showlegend":true,"text":[1.0],"textposition":"outside","x":["start up project"],"xaxis":"x","y":[1],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"skill=%{x}<br>vacancies=%{text}<extra></extra>","legendgroup":"\u043f\u0440\u043e\u0432\u0435\u0434\u0435\u043d\u0438\u0435 \u0442\u0435\u0441\u0442\u0438\u0440\u043e\u0432\u0430\u043d\u0438\u0439","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"\u043f\u0440\u043e\u0432\u0435\u0434\u0435\u043d\u0438\u0435 \u0442\u0435\u0441\u0442\u0438\u0440\u043e\u0432\u0430\u043d\u0438\u0439 (25.00% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)","offsetgroup":"\u043f\u0440\u043e\u0432\u0435\u0434\u0435\u043d\u0438\u0435 \u0442\u0435\u0441\u0442\u0438\u0440\u043e\u0432\u0430\u043d\u0438\u0439","orientation":"v","showlegend":true,"text":[1.0],"textposition":"outside","x":["\u043f\u0440\u043e\u0432\u0435\u0434\u0435\u043d\u0438\u0435 \u0442\u0435\u0441\u0442\u0438\u0440\u043e\u0432\u0430\u043d\u0438\u0439"],"xaxis":"x","y":[1],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"skill=%{x}<br>vacancies=%{text}<extra></extra>","legendgroup":"\u0431\u0430\u0437\u044b \u0434\u0430\u043d\u043d\u044b\u0445","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"\u0431\u0430\u0437\u044b \u0434\u0430\u043d\u043d\u044 ...

# %% [markdown]
# ## ТОП 15 работодателей

# %%
df['employer_list'] = df['employer'].apply(lambda x: x.split(', '))
df

employer_list = []
skills_data_analyst = []
skills_business_analyst = []

lists = {
    'аналитик данных':skills_data_analyst,
    'бизнес аналитик':skills_business_analyst
}


for keyword in lists:
    for skills in df.query('category==@keyword')['employer_list']:
        for skill in skills:
            if skill != 'неизвестно':
                lists[keyword].append(skill)

employer_list = skills_data_analyst + skills_business_analyst
  

skills_data_analyst_df = pd.DataFrame({'skill':skills_data_analyst})
skills_business_analyst_df = pd.DataFrame({'skill':skills_business_analyst})
skills = pd.DataFrame({'skill':employer_list})

skills_data_analyst_df = pd.DataFrame(skills_data_analyst_df['skill'].value_counts()).reset_index()
skills_business_analyst_df = pd.DataFrame(skills_business_analyst_df['skill'].value_counts()).reset_index()
skills = pd.DataFrame(skills['skill'].value_counts()).reset_index()

skills_data_analyst_df.columns = ['skill', 'vacancies']
skills_business_analyst_df.columns = ['skill', 'vacancies']
skills.columns = ['skill', 'vacancies']

skills_data_analyst_df['percent_of_vacancies'] = skills_data_analyst_df['vacancies'] / len(df.query('employer != "неизвестно" and category=="аналитик данных"'))
skills_business_analyst_df['percent_of_vacancies'] = skills_business_analyst_df['vacancies'] / len(df.query('employer != "неизвестно" and category=="бизнес аналитик"'))
skills['percent_of_vacancies'] = skills['vacancies'] / len(df.query('employer != "неизвестно"'))

lists_for_plots = {
    'аналитик данных':skills_data_analyst_df,
    'бизнес аналитик':skills_business_analyst_df, 
    'аналитик данных / бизнес аналитик':skills
}

for keyword in lists_for_plots:
    fig = px.bar(lists_for_plots[keyword].head(15), x='skill', y='vacancies', width = 950, height = 450, color='skill', text='vacancies')
    fig.update_xaxes(tickangle=30)
    fig.update_layout(
        title='ТОП-15 работодателей в профессии {} '.format(keyword),
        xaxis_title="Работодатели",
        yaxis_title="количество вакансий")
    fig.update_traces(textposition='outside')
    for trace, percent in zip(fig.data, lists_for_plots[keyword].head(15)['percent_of_vacancies']):
        trace.name = trace.name.split('=')[0] + ' (' + '{:.2%}'.format(percent) + ' вакансий)'


    fig.show()
# Out:
# <div>                            <div id="b0126706-6a27-4c32-a60b-3c7595ce51da" class="plotly-graph-div" style="height:450px; width:950px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b0126706-6a27-4c32-a60b-3c7595ce51da")) {                    Plotly.newPlot(                        "b0126706-6a27-4c32-a60b-3c7595ce51da",                        [{"alignmentgroup":"True","hovertemplate":"skill=%{x}<br>vacancies=%{text}<extra></extra>","legendgroup":"\u0441\u0431\u0435\u0440","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"\u0441\u0431\u0435\u0440 (17.60% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)","offsetgroup":"\u0441\u0431\u0435\u0440","orientation":"v","showlegend":true,"text":[63.0],"textposition":"outside","x":["\u0441\u0431\u0435\u0440"],"xaxis":"x","y":[63],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"skill=%{x}<br>vacancies=%{text}<extra></extra>","legendgroup":"wildberries","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"wildberries (2.23% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)","offsetgroup":"wildberries","orientation":"v","showlegend":true,"text":[8.0],"textposition":"outside","x":["wildberries"],"xaxis":"x","y":[8],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"skill=%{x}<br>vacancies=%{text}<extra></extra>","legendgroup":"\u04421","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"\u04421 (1.96% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)","offsetgroup":"\u04421","orientation":"v","showlegend":true,"text":[7.0],"textposition":"outside","x":["\u04421"],"xaxis":"x","y":[7],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"skill=%{x}<br>vacancies=%{text}<extra></extra>","legendgroup":"ozon","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"ozon (1.96% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)","offsetgroup":"ozon","orientation":"v","showlegend":true,"text":[7.0],"textposition":"outside","x":["ozon"],"xaxis":"x","y":[7],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"skill=%{x}<br>vacancies=%{text}<extra></extra>","legendgroup":"\u043c\u0442\u0441","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"\u043c\u0442\u0441 (1.96% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)","offsetgroup":"\u043c\u0442\u0441","orientation":"v","showlegend":true,"text":[7.0],"textposition":"outside","x":["\u043c\u0442\u0441"],"xaxis":"x","y":[7],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"skill=%{x}<br>vacancies=%{text}<extra></extra>","legendgroup":"axenix (\u0440\u0430\u043d\u0435\u0435 accenture)","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"axenix (\u0440\u0430\u043d\u0435\u0435 accenture) (1.68% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)","offsetgroup":"axenix (\u0440\u0430\u043d\u0435\u0435 accenture)","orientation":"v","showlegend":true,"text":[6.0],"textposition":"outside","x":["axenix (\u0440\u0430\u043d\u0435\u0435 accenture)"],"xaxis":"x","y":[6],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"skill=%{x}<br>vacancies=%{text}<extra></extra>","legendgroup":"\u0446\u0435\u043d\u0442\u0440 \u0444\u0438\u043d\u0430\u043d\u0441\u043e\u0432\u044b\u0445 \u0442\u0435\u0445\u043d\u043e\u043b\u043e\u0433\u0438\u0439","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"\u0446\u0435\u043d\u0442\u0440 \u0444\u0438\u043d\u0430\u043d\u0441\u043e\u0432\u044b\u0445 \u0442\u0435\u0445\u043d\u043e\u043b\u043e\u0433\u0438\u0439 (1.68% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)","offsetgroup":"\u0446\u0435\u043d\u0442\u0440 \u0444\u0438\u043d\u0430\u043d\u0441\u043e\u0432\u044b\u0445 \u0442\u0435\u0445\u043d\u043e\u043b\u043e\u0433\u0438\u0439","orientation":"v","showlegend":true,"text":[6.0],"textposition":"outside","x":["\u ...
# <div>                            <div id="1156d0eb-19e2-4e06-9e6f-370c6433a9c5" class="plotly-graph-div" style="height:450px; width:950px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1156d0eb-19e2-4e06-9e6f-370c6433a9c5")) {                    Plotly.newPlot(                        "1156d0eb-19e2-4e06-9e6f-370c6433a9c5",                        [{"alignmentgroup":"True","hovertemplate":"skill=%{x}<br>vacancies=%{text}<extra></extra>","legendgroup":"\u0441\u0431\u0435\u0440","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"\u0441\u0431\u0435\u0440 (3.46% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)","offsetgroup":"\u0441\u0431\u0435\u0440","orientation":"v","showlegend":true,"text":[32.0],"textposition":"outside","x":["\u0441\u0431\u0435\u0440"],"xaxis":"x","y":[32],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"skill=%{x}<br>vacancies=%{text}<extra></extra>","legendgroup":"\u0440\u043e\u0437\u043d\u0438\u0447\u043d\u0430\u044f \u0441\u0435\u0442\u044c","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"\u0440\u043e\u0437\u043d\u0438\u0447\u043d\u0430\u044f \u0441\u0435\u0442\u044c (2.92% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)","offsetgroup":"\u0440\u043e\u0437\u043d\u0438\u0447\u043d\u0430\u044f \u0441\u0435\u0442\u044c","orientation":"v","showlegend":true,"text":[27.0],"textposition":"outside","x":["\u0440\u043e\u0437\u043d\u0438\u0447\u043d\u0430\u044f \u0441\u0435\u0442\u044c"],"xaxis":"x","y":[27],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"skill=%{x}<br>vacancies=%{text}<extra></extra>","legendgroup":"\u043c\u0430\u0433\u043d\u0438\u0442","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"\u043c\u0430\u0433\u043d\u0438\u0442 (2.92% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)","offsetgroup":"\u043c\u0430\u0433\u043d\u0438\u0442","orientation":"v","showlegend":true,"text":[27.0],"textposition":"outside","x":["\u043c\u0430\u0433\u043d\u0438\u0442"],"xaxis":"x","y":[27],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"skill=%{x}<br>vacancies=%{text}<extra></extra>","legendgroup":"\u0431\u0430\u043d\u043a \u0432\u0442\u0431 (\u043f\u0430\u043e)","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"\u0431\u0430\u043d\u043a \u0432\u0442\u0431 (\u043f\u0430\u043e) (2.16% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)","offsetgroup":"\u0431\u0430\u043d\u043a \u0432\u0442\u0431 (\u043f\u0430\u043e)","orientation":"v","showlegend":true,"text":[20.0],"textposition":"outside","x":["\u0431\u0430\u043d\u043a \u0432\u0442\u0431 (\u043f\u0430\u043e)"],"xaxis":"x","y":[20],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"skill=%{x}<br>vacancies=%{text}<extra></extra>","legendgroup":"\u04421","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"\u04421 (1.73% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)","offsetgroup":"\u04421","orientation":"v","showlegend":true,"text":[16.0],"textposition":"outside","x":["\u04421"],"xaxis":"x","y":[16],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"skill=%{x}<br>vacancies=%{text}<extra></extra>","legendgroup":"\u043a\u043e\u043c\u0443\u0441","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"\u043a\u043e\u043c\u0443\u0441 (1.40% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)","offsetgroup":"\u043a\u043e\u043c\u0443\u0441","orientation":"v","showlegend":true,"text":[13.0],"textposition":"outside","x":["\u043a\u043e\u043c\u0443\u0441"],"xaxis":"x","y":[13],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"skill=%{x}<br>vacancies=%{text}<extra></extra>","legendgroup":"\u0433\u0440\u0443\u043f\u043f\u0430 \u043a\u043e\u043c\u043f\u0430\u043d\u0438\u0439","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"\u0433\u0440 ...
# <div>                            <div id="e9b99677-26d0-4990-89f2-b7d724e1584f" class="plotly-graph-div" style="height:450px; width:950px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e9b99677-26d0-4990-89f2-b7d724e1584f")) {                    Plotly.newPlot(                        "e9b99677-26d0-4990-89f2-b7d724e1584f",                        [{"alignmentgroup":"True","hovertemplate":"skill=%{x}<br>vacancies=%{text}<extra></extra>","legendgroup":"\u0441\u0431\u0435\u0440","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"\u0441\u0431\u0435\u0440 (7.40% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)","offsetgroup":"\u0441\u0431\u0435\u0440","orientation":"v","showlegend":true,"text":[95.0],"textposition":"outside","x":["\u0441\u0431\u0435\u0440"],"xaxis":"x","y":[95],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"skill=%{x}<br>vacancies=%{text}<extra></extra>","legendgroup":"\u043c\u0430\u0433\u043d\u0438\u0442","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"\u043c\u0430\u0433\u043d\u0438\u0442 (2.34% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)","offsetgroup":"\u043c\u0430\u0433\u043d\u0438\u0442","orientation":"v","showlegend":true,"text":[30.0],"textposition":"outside","x":["\u043c\u0430\u0433\u043d\u0438\u0442"],"xaxis":"x","y":[30],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"skill=%{x}<br>vacancies=%{text}<extra></extra>","legendgroup":"\u0440\u043e\u0437\u043d\u0438\u0447\u043d\u0430\u044f \u0441\u0435\u0442\u044c","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"\u0440\u043e\u0437\u043d\u0438\u0447\u043d\u0430\u044f \u0441\u0435\u0442\u044c (2.34% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)","offsetgroup":"\u0440\u043e\u0437\u043d\u0438\u0447\u043d\u0430\u044f \u0441\u0435\u0442\u044c","orientation":"v","showlegend":true,"text":[30.0],"textposition":"outside","x":["\u0440\u043e\u0437\u043d\u0438\u0447\u043d\u0430\u044f \u0441\u0435\u0442\u044c"],"xaxis":"x","y":[30],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"skill=%{x}<br>vacancies=%{text}<extra></extra>","legendgroup":"\u0431\u0430\u043d\u043a \u0432\u0442\u0431 (\u043f\u0430\u043e)","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"\u0431\u0430\u043d\u043a \u0432\u0442\u0431 (\u043f\u0430\u043e) (1.87% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)","offsetgroup":"\u0431\u0430\u043d\u043a \u0432\u0442\u0431 (\u043f\u0430\u043e)","orientation":"v","showlegend":true,"text":[24.0],"textposition":"outside","x":["\u0431\u0430\u043d\u043a \u0432\u0442\u0431 (\u043f\u0430\u043e)"],"xaxis":"x","y":[24],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"skill=%{x}<br>vacancies=%{text}<extra></extra>","legendgroup":"\u04421","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"\u04421 (1.79% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)","offsetgroup":"\u04421","orientation":"v","showlegend":true,"text":[23.0],"textposition":"outside","x":["\u04421"],"xaxis":"x","y":[23],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"skill=%{x}<br>vacancies=%{text}<extra></extra>","legendgroup":"ozon","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"ozon (1.17% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)","offsetgroup":"ozon","orientation":"v","showlegend":true,"text":[15.0],"textposition":"outside","x":["ozon"],"xaxis":"x","y":[15],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"skill=%{x}<br>vacancies=%{text}<extra></extra>","legendgroup":"\u043a\u043e\u043c\u0443\u0441","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"\u043a\u043e\u043c\u0443\u0441 (1.09% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)","offsetgroup":"\u043a\u043e\u043c\u0443\u0441","orientation":"v","showlegend":true ...

# %% [markdown]
# ## ТОП 15 городов России по предлагаемым вакансиям

# %%
df['area_list'] = df['area'].apply(lambda x: x.split(', '))
df

area_list = []
skills_data_analyst = []
skills_business_analyst = []

lists = {
    'аналитик данных':skills_data_analyst,
    'бизнес аналитик':skills_business_analyst
}


for keyword in lists:
    for skills in df.query('category==@keyword')['area_list']:
        for skill in skills:
            if skill!='неизвестно':
                lists[keyword].append(skill)

skills_list = skills_data_analyst + skills_business_analyst
  

skills_data_analyst_df = pd.DataFrame({'skill':skills_data_analyst})
skills_business_analyst_df = pd.DataFrame({'skill':skills_business_analyst})
skills = pd.DataFrame({'skill':skills_list})

skills_data_analyst_df = pd.DataFrame(skills_data_analyst_df['skill'].value_counts()).reset_index()
skills_business_analyst_df = pd.DataFrame(skills_business_analyst_df['skill'].value_counts()).reset_index()
skills = pd.DataFrame(skills['skill'].value_counts()).reset_index()

skills_data_analyst_df.columns = ['skill', 'vacancies']
skills_business_analyst_df.columns = ['skill', 'vacancies']
skills.columns = ['skill', 'vacancies']

skills_data_analyst_df['percent_of_vacancies'] = skills_data_analyst_df['vacancies'] / len(df.query('area != "неизвестно" and category=="аналитик данных"'))
skills_business_analyst_df['percent_of_vacancies'] = skills_business_analyst_df['vacancies'] / len(df.query('area != "неизвестно" and category=="бизнес аналитик"'))
skills['percent_of_vacancies'] = skills['vacancies'] / len(df.query('area != "неизвестно"'))

lists_for_plots = {
    'аналитик данных':skills_data_analyst_df,
    'бизнес аналитик':skills_business_analyst_df, 
    'аналитик данных / бизнес аналитик':skills
}

for keyword in lists_for_plots:
    fig = px.bar(lists_for_plots[keyword].head(15), x='skill', y='vacancies', width = 950, height = 450, color='skill', text='vacancies')
    fig.update_xaxes(tickangle=30)
    fig.update_layout(
        title='ТОП-15 городов по профессии {} '.format(keyword),
        xaxis_title="название города",
        yaxis_title="количество вакансий")
    fig.update_traces(textposition='outside')
    for trace, percent in zip(fig.data, lists_for_plots[keyword].head(15)['percent_of_vacancies']):
        trace.name = trace.name.split('=')[0] + ' (' + '{:.2%}'.format(percent) + ' вакансий)'


    fig.show()
# Out:
# <div>                            <div id="33e8ada8-899f-4ced-8652-0ed75110b41f" class="plotly-graph-div" style="height:450px; width:950px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("33e8ada8-899f-4ced-8652-0ed75110b41f")) {                    Plotly.newPlot(                        "33e8ada8-899f-4ced-8652-0ed75110b41f",                        [{"alignmentgroup":"True","hovertemplate":"skill=%{x}<br>vacancies=%{text}<extra></extra>","legendgroup":"\u043c\u043e\u0441\u043a\u0432\u0430","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"\u043c\u043e\u0441\u043a\u0432\u0430 (69.83% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)","offsetgroup":"\u043c\u043e\u0441\u043a\u0432\u0430","orientation":"v","showlegend":true,"text":[250.0],"textposition":"outside","x":["\u043c\u043e\u0441\u043a\u0432\u0430"],"xaxis":"x","y":[250],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"skill=%{x}<br>vacancies=%{text}<extra></extra>","legendgroup":"\u0441\u0430\u043d\u043a\u0442-\u043f\u0435\u0442\u0435\u0440\u0431\u0443\u0440\u0433","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"\u0441\u0430\u043d\u043a\u0442-\u043f\u0435\u0442\u0435\u0440\u0431\u0443\u0440\u0433 (7.82% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)","offsetgroup":"\u0441\u0430\u043d\u043a\u0442-\u043f\u0435\u0442\u0435\u0440\u0431\u0443\u0440\u0433","orientation":"v","showlegend":true,"text":[28.0],"textposition":"outside","x":["\u0441\u0430\u043d\u043a\u0442-\u043f\u0435\u0442\u0435\u0440\u0431\u0443\u0440\u0433"],"xaxis":"x","y":[28],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"skill=%{x}<br>vacancies=%{text}<extra></extra>","legendgroup":"\u043a\u0430\u0437\u0430\u043d\u044c","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"\u043a\u0430\u0437\u0430\u043d\u044c (1.96% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)","offsetgroup":"\u043a\u0430\u0437\u0430\u043d\u044c","orientation":"v","showlegend":true,"text":[7.0],"textposition":"outside","x":["\u043a\u0430\u0437\u0430\u043d\u044c"],"xaxis":"x","y":[7],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"skill=%{x}<br>vacancies=%{text}<extra></extra>","legendgroup":"\u0435\u043a\u0430\u0442\u0435\u0440\u0438\u043d\u0431\u0443\u0440\u0433","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"\u0435\u043a\u0430\u0442\u0435\u0440\u0438\u043d\u0431\u0443\u0440\u0433 (1.96% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)","offsetgroup":"\u0435\u043a\u0430\u0442\u0435\u0440\u0438\u043d\u0431\u0443\u0440\u0433","orientation":"v","showlegend":true,"text":[7.0],"textposition":"outside","x":["\u0435\u043a\u0430\u0442\u0435\u0440\u0438\u043d\u0431\u0443\u0440\u0433"],"xaxis":"x","y":[7],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"skill=%{x}<br>vacancies=%{text}<extra></extra>","legendgroup":"\u043d\u0438\u0436\u043d\u0438\u0439 \u043d\u043e\u0432\u0433\u043e\u0440\u043e\u0434","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"\u043d\u0438\u0436\u043d\u0438\u0439 \u043d\u043e\u0432\u0433\u043e\u0440\u043e\u0434 (1.96% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)","offsetgroup":"\u043d\u0438\u0436\u043d\u0438\u0439 \u043d\u043e\u0432\u0433\u043e\u0440\u043e\u0434","orientation":"v","showlegend":true,"text":[7.0],"textposition":"outside","x":["\u043d\u0438\u0436\u043d\u0438\u0439 \u043d\u043e\u0432\u0433\u043e\u0440\u043e\u0434"],"xaxis":"x","y":[7],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"skill=%{x}<br>vacancies=%{text}<extra></extra>","legendgroup":"\u043a\u0440\u0430\u0441\u043d\u043e\u0434\u0430\u0440","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"\u043a\u0440\u0430\u0441\u043d\u043e\u0434\u0430\u0440 (1.96% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)","offsetgrou ...
# <div>                            <div id="a5c6aadf-c364-45cf-935c-cae6debdc9b5" class="plotly-graph-div" style="height:450px; width:950px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a5c6aadf-c364-45cf-935c-cae6debdc9b5")) {                    Plotly.newPlot(                        "a5c6aadf-c364-45cf-935c-cae6debdc9b5",                        [{"alignmentgroup":"True","hovertemplate":"skill=%{x}<br>vacancies=%{text}<extra></extra>","legendgroup":"\u043c\u043e\u0441\u043a\u0432\u0430","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"\u043c\u043e\u0441\u043a\u0432\u0430 (59.50% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)","offsetgroup":"\u043c\u043e\u0441\u043a\u0432\u0430","orientation":"v","showlegend":true,"text":[551.0],"textposition":"outside","x":["\u043c\u043e\u0441\u043a\u0432\u0430"],"xaxis":"x","y":[551],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"skill=%{x}<br>vacancies=%{text}<extra></extra>","legendgroup":"\u0441\u0430\u043d\u043a\u0442-\u043f\u0435\u0442\u0435\u0440\u0431\u0443\u0440\u0433","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"\u0441\u0430\u043d\u043a\u0442-\u043f\u0435\u0442\u0435\u0440\u0431\u0443\u0440\u0433 (10.26% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)","offsetgroup":"\u0441\u0430\u043d\u043a\u0442-\u043f\u0435\u0442\u0435\u0440\u0431\u0443\u0440\u0433","orientation":"v","showlegend":true,"text":[95.0],"textposition":"outside","x":["\u0441\u0430\u043d\u043a\u0442-\u043f\u0435\u0442\u0435\u0440\u0431\u0443\u0440\u0433"],"xaxis":"x","y":[95],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"skill=%{x}<br>vacancies=%{text}<extra></extra>","legendgroup":"\u0435\u043a\u0430\u0442\u0435\u0440\u0438\u043d\u0431\u0443\u0440\u0433","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"\u0435\u043a\u0430\u0442\u0435\u0440\u0438\u043d\u0431\u0443\u0440\u0433 (2.81% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)","offsetgroup":"\u0435\u043a\u0430\u0442\u0435\u0440\u0438\u043d\u0431\u0443\u0440\u0433","orientation":"v","showlegend":true,"text":[26.0],"textposition":"outside","x":["\u0435\u043a\u0430\u0442\u0435\u0440\u0438\u043d\u0431\u0443\u0440\u0433"],"xaxis":"x","y":[26],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"skill=%{x}<br>vacancies=%{text}<extra></extra>","legendgroup":"\u043d\u0438\u0436\u043d\u0438\u0439 \u043d\u043e\u0432\u0433\u043e\u0440\u043e\u0434","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"\u043d\u0438\u0436\u043d\u0438\u0439 \u043d\u043e\u0432\u0433\u043e\u0440\u043e\u0434 (2.38% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)","offsetgroup":"\u043d\u0438\u0436\u043d\u0438\u0439 \u043d\u043e\u0432\u0433\u043e\u0440\u043e\u0434","orientation":"v","showlegend":true,"text":[22.0],"textposition":"outside","x":["\u043d\u0438\u0436\u043d\u0438\u0439 \u043d\u043e\u0432\u0433\u043e\u0440\u043e\u0434"],"xaxis":"x","y":[22],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"skill=%{x}<br>vacancies=%{text}<extra></extra>","legendgroup":"\u043a\u0430\u0437\u0430\u043d\u044c","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"\u043a\u0430\u0437\u0430\u043d\u044c (2.27% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)","offsetgroup":"\u043a\u0430\u0437\u0430\u043d\u044c","orientation":"v","showlegend":true,"text":[21.0],"textposition":"outside","x":["\u043a\u0430\u0437\u0430\u043d\u044c"],"xaxis":"x","y":[21],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"skill=%{x}<br>vacancies=%{text}<extra></extra>","legendgroup":"\u043a\u0440\u0430\u0441\u043d\u043e\u0434\u0430\u0440","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"\u043a\u0440\u0430\u0441\u043d\u043e\u0434\u0430\u0440 (2.16% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)","off ...
# <div>                            <div id="4ce65ff9-6151-4f62-ae80-a30ee70e447e" class="plotly-graph-div" style="height:450px; width:950px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4ce65ff9-6151-4f62-ae80-a30ee70e447e")) {                    Plotly.newPlot(                        "4ce65ff9-6151-4f62-ae80-a30ee70e447e",                        [{"alignmentgroup":"True","hovertemplate":"skill=%{x}<br>vacancies=%{text}<extra></extra>","legendgroup":"\u043c\u043e\u0441\u043a\u0432\u0430","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"\u043c\u043e\u0441\u043a\u0432\u0430 (62.38% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)","offsetgroup":"\u043c\u043e\u0441\u043a\u0432\u0430","orientation":"v","showlegend":true,"text":[801.0],"textposition":"outside","x":["\u043c\u043e\u0441\u043a\u0432\u0430"],"xaxis":"x","y":[801],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"skill=%{x}<br>vacancies=%{text}<extra></extra>","legendgroup":"\u0441\u0430\u043d\u043a\u0442-\u043f\u0435\u0442\u0435\u0440\u0431\u0443\u0440\u0433","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"\u0441\u0430\u043d\u043a\u0442-\u043f\u0435\u0442\u0435\u0440\u0431\u0443\u0440\u0433 (9.58% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)","offsetgroup":"\u0441\u0430\u043d\u043a\u0442-\u043f\u0435\u0442\u0435\u0440\u0431\u0443\u0440\u0433","orientation":"v","showlegend":true,"text":[123.0],"textposition":"outside","x":["\u0441\u0430\u043d\u043a\u0442-\u043f\u0435\u0442\u0435\u0440\u0431\u0443\u0440\u0433"],"xaxis":"x","y":[123],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"skill=%{x}<br>vacancies=%{text}<extra></extra>","legendgroup":"\u0435\u043a\u0430\u0442\u0435\u0440\u0438\u043d\u0431\u0443\u0440\u0433","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"\u0435\u043a\u0430\u0442\u0435\u0440\u0438\u043d\u0431\u0443\u0440\u0433 (2.57% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)","offsetgroup":"\u0435\u043a\u0430\u0442\u0435\u0440\u0438\u043d\u0431\u0443\u0440\u0433","orientation":"v","showlegend":true,"text":[33.0],"textposition":"outside","x":["\u0435\u043a\u0430\u0442\u0435\u0440\u0438\u043d\u0431\u0443\u0440\u0433"],"xaxis":"x","y":[33],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"skill=%{x}<br>vacancies=%{text}<extra></extra>","legendgroup":"\u043d\u0438\u0436\u043d\u0438\u0439 \u043d\u043e\u0432\u0433\u043e\u0440\u043e\u0434","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"\u043d\u0438\u0436\u043d\u0438\u0439 \u043d\u043e\u0432\u0433\u043e\u0440\u043e\u0434 (2.26% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)","offsetgroup":"\u043d\u0438\u0436\u043d\u0438\u0439 \u043d\u043e\u0432\u0433\u043e\u0440\u043e\u0434","orientation":"v","showlegend":true,"text":[29.0],"textposition":"outside","x":["\u043d\u0438\u0436\u043d\u0438\u0439 \u043d\u043e\u0432\u0433\u043e\u0440\u043e\u0434"],"xaxis":"x","y":[29],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"skill=%{x}<br>vacancies=%{text}<extra></extra>","legendgroup":"\u043a\u0430\u0437\u0430\u043d\u044c","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"\u043a\u0430\u0437\u0430\u043d\u044c (2.18% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)","offsetgroup":"\u043a\u0430\u0437\u0430\u043d\u044c","orientation":"v","showlegend":true,"text":[28.0],"textposition":"outside","x":["\u043a\u0430\u0437\u0430\u043d\u044c"],"xaxis":"x","y":[28],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"skill=%{x}<br>vacancies=%{text}<extra></extra>","legendgroup":"\u043a\u0440\u0430\u0441\u043d\u043e\u0434\u0430\u0440","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"\u043a\u0440\u0430\u0441\u043d\u043e\u0434\u0430\u0440 (2.10% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)","of ...

# %%
df.columns
# Out:
# Index(['id', 'name', 'published_at', 'alternate_url', 'type', 'employer',
#        'department', 'area', 'experience', 'key_skills', 'schedule',
#        'employment', 'description', 'description_lemmatized', 'salary_from',
#        'salary_to', 'salary_bin', 'key_skills_from_key_skills_field',
#        'hard_skills_from_description', 'soft_skills_from_description',
#        'category', 'skills_list', 'employer_list', 'area_list'],
#       dtype='object')

# %% [markdown]
# ## Типы предлагаемой занятости по вакансиям

# %%
df['schedule_list'] = df['schedule'].apply(lambda x: x.split(', '))
df

schedule_list = []
skills_data_analyst = []
skills_business_analyst = []

lists = {
    'аналитик данных':skills_data_analyst,
    'бизнес аналитик':skills_business_analyst
}


for keyword in lists:
    for skills in df.query('category==@keyword')['schedule_list']:
        for skill in skills:
            if skill!='неизвестно':
                lists[keyword].append(skill)

schedule_list = skills_data_analyst + skills_business_analyst
  

skills_data_analyst_df = pd.DataFrame({'skill':skills_data_analyst})
skills_business_analyst_df = pd.DataFrame({'skill':skills_business_analyst})
skills = pd.DataFrame({'skill':schedule_list})

skills_data_analyst_df = pd.DataFrame(skills_data_analyst_df['skill'].value_counts()).reset_index()
skills_business_analyst_df = pd.DataFrame(skills_business_analyst_df['skill'].value_counts()).reset_index()
skills = pd.DataFrame(skills['skill'].value_counts()).reset_index()

skills_data_analyst_df.columns = ['skill', 'vacancies']
skills_business_analyst_df.columns = ['skill', 'vacancies']
skills.columns = ['skill', 'vacancies']

skills_data_analyst_df['percent_of_vacancies'] = skills_data_analyst_df['vacancies'] / len(df.query('schedule != "неизвестно" and category=="аналитик данных"'))
skills_business_analyst_df['percent_of_vacancies'] = skills_business_analyst_df['vacancies'] / len(df.query('schedule != "неизвестно" and category=="бизнес аналитик"'))
skills['percent_of_vacancies'] = skills['vacancies'] / len(df.query('schedule != "неизвестно"'))

lists_for_plots = {
    'аналитик данных':skills_data_analyst_df,
    'бизнес аналитик':skills_business_analyst_df, 
    'аналитик данных / бизнес аналитик':skills
}

for keyword in lists_for_plots:
    fig = px.bar(lists_for_plots[keyword].head(15), x='skill', y='vacancies', width = 950, height = 450, color='skill', text='vacancies')
    fig.update_xaxes(tickangle=30)
    fig.update_layout(
        title='Занятость по вакансии {} '.format(keyword),
        xaxis_title="название типа занятости",
        yaxis_title="количество вакансий")
    fig.update_traces(textposition='outside')
    for trace, percent in zip(fig.data, lists_for_plots[keyword].head(15)['percent_of_vacancies']):
        trace.name = trace.name.split('=')[0] + ' (' + '{:.2%}'.format(percent) + ' вакансий)'


    fig.show()
# Out:
# <div>                            <div id="face8551-ab1a-47d2-a73c-2575629989d1" class="plotly-graph-div" style="height:450px; width:950px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("face8551-ab1a-47d2-a73c-2575629989d1")) {                    Plotly.newPlot(                        "face8551-ab1a-47d2-a73c-2575629989d1",                        [{"alignmentgroup":"True","hovertemplate":"skill=%{x}<br>vacancies=%{text}<extra></extra>","legendgroup":"\u043f\u043e\u043b\u043d\u044b\u0439 \u0434\u0435\u043d\u044c","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"\u043f\u043e\u043b\u043d\u044b\u0439 \u0434\u0435\u043d\u044c (84.08% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)","offsetgroup":"\u043f\u043e\u043b\u043d\u044b\u0439 \u0434\u0435\u043d\u044c","orientation":"v","showlegend":true,"text":[301.0],"textposition":"outside","x":["\u043f\u043e\u043b\u043d\u044b\u0439 \u0434\u0435\u043d\u044c"],"xaxis":"x","y":[301],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"skill=%{x}<br>vacancies=%{text}<extra></extra>","legendgroup":"\u0443\u0434\u0430\u043b\u0435\u043d\u043d\u0430\u044f \u0440\u0430\u0431\u043e\u0442\u0430","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"\u0443\u0434\u0430\u043b\u0435\u043d\u043d\u0430\u044f \u0440\u0430\u0431\u043e\u0442\u0430 (13.69% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)","offsetgroup":"\u0443\u0434\u0430\u043b\u0435\u043d\u043d\u0430\u044f \u0440\u0430\u0431\u043e\u0442\u0430","orientation":"v","showlegend":true,"text":[49.0],"textposition":"outside","x":["\u0443\u0434\u0430\u043b\u0435\u043d\u043d\u0430\u044f \u0440\u0430\u0431\u043e\u0442\u0430"],"xaxis":"x","y":[49],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"skill=%{x}<br>vacancies=%{text}<extra></extra>","legendgroup":"\u0433\u0438\u0431\u043a\u0438\u0439 \u0433\u0440\u0430\u0444\u0438\u043a","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"\u0433\u0438\u0431\u043a\u0438\u0439 \u0433\u0440\u0430\u0444\u0438\u043a (1.68% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)","offsetgroup":"\u0433\u0438\u0431\u043a\u0438\u0439 \u0433\u0440\u0430\u0444\u0438\u043a","orientation":"v","showlegend":true,"text":[6.0],"textposition":"outside","x":["\u0433\u0438\u0431\u043a\u0438\u0439 \u0433\u0440\u0430\u0444\u0438\u043a"],"xaxis":"x","y":[6],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"skill=%{x}<br>vacancies=%{text}<extra></extra>","legendgroup":"\u0441\u043c\u0435\u043d\u043d\u044b\u0439 \u0433\u0440\u0430\u0444\u0438\u043a","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"\u0441\u043c\u0435\u043d\u043d\u044b\u0439 \u0433\u0440\u0430\u0444\u0438\u043a (0.56% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)","offsetgroup":"\u0441\u043c\u0435\u043d\u043d\u044b\u0439 \u0433\u0440\u0430\u0444\u0438\u043a","orientation":"v","showlegend":true,"text":[2.0],"textposition":"outside","x":["\u0441\u043c\u0435\u043d\u043d\u044b\u0439 \u0433\u0440\u0430\u0444\u0438\u043a"],"xaxis":"x","y":[2],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.55555555 ...
# <div>                            <div id="0c18d365-4dab-48f7-b490-0e930f15f302" class="plotly-graph-div" style="height:450px; width:950px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0c18d365-4dab-48f7-b490-0e930f15f302")) {                    Plotly.newPlot(                        "0c18d365-4dab-48f7-b490-0e930f15f302",                        [{"alignmentgroup":"True","hovertemplate":"skill=%{x}<br>vacancies=%{text}<extra></extra>","legendgroup":"\u043f\u043e\u043b\u043d\u044b\u0439 \u0434\u0435\u043d\u044c","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"\u043f\u043e\u043b\u043d\u044b\u0439 \u0434\u0435\u043d\u044c (80.35% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)","offsetgroup":"\u043f\u043e\u043b\u043d\u044b\u0439 \u0434\u0435\u043d\u044c","orientation":"v","showlegend":true,"text":[744.0],"textposition":"outside","x":["\u043f\u043e\u043b\u043d\u044b\u0439 \u0434\u0435\u043d\u044c"],"xaxis":"x","y":[744],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"skill=%{x}<br>vacancies=%{text}<extra></extra>","legendgroup":"\u0443\u0434\u0430\u043b\u0435\u043d\u043d\u0430\u044f \u0440\u0430\u0431\u043e\u0442\u0430","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"\u0443\u0434\u0430\u043b\u0435\u043d\u043d\u0430\u044f \u0440\u0430\u0431\u043e\u0442\u0430 (16.74% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)","offsetgroup":"\u0443\u0434\u0430\u043b\u0435\u043d\u043d\u0430\u044f \u0440\u0430\u0431\u043e\u0442\u0430","orientation":"v","showlegend":true,"text":[155.0],"textposition":"outside","x":["\u0443\u0434\u0430\u043b\u0435\u043d\u043d\u0430\u044f \u0440\u0430\u0431\u043e\u0442\u0430"],"xaxis":"x","y":[155],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"skill=%{x}<br>vacancies=%{text}<extra></extra>","legendgroup":"\u0433\u0438\u0431\u043a\u0438\u0439 \u0433\u0440\u0430\u0444\u0438\u043a","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"\u0433\u0438\u0431\u043a\u0438\u0439 \u0433\u0440\u0430\u0444\u0438\u043a (2.81% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)","offsetgroup":"\u0433\u0438\u0431\u043a\u0438\u0439 \u0433\u0440\u0430\u0444\u0438\u043a","orientation":"v","showlegend":true,"text":[26.0],"textposition":"outside","x":["\u0433\u0438\u0431\u043a\u0438\u0439 \u0433\u0440\u0430\u0444\u0438\u043a"],"xaxis":"x","y":[26],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"skill=%{x}<br>vacancies=%{text}<extra></extra>","legendgroup":"\u0441\u043c\u0435\u043d\u043d\u044b\u0439 \u0433\u0440\u0430\u0444\u0438\u043a","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"\u0441\u043c\u0435\u043d\u043d\u044b\u0439 \u0433\u0440\u0430\u0444\u0438\u043a (0.11% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)","offsetgroup":"\u0441\u043c\u0435\u043d\u043d\u044b\u0439 \u0433\u0440\u0430\u0444\u0438\u043a","orientation":"v","showlegend":true,"text":[1.0],"textposition":"outside","x":["\u0441\u043c\u0435\u043d\u043d\u044b\u0439 \u0433\u0440\u0430\u0444\u0438\u043a"],"xaxis":"x","y":[1],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555 ...
# <div>                            <div id="eb216742-5032-4019-ab87-ed227a4b76e9" class="plotly-graph-div" style="height:450px; width:950px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("eb216742-5032-4019-ab87-ed227a4b76e9")) {                    Plotly.newPlot(                        "eb216742-5032-4019-ab87-ed227a4b76e9",                        [{"alignmentgroup":"True","hovertemplate":"skill=%{x}<br>vacancies=%{text}<extra></extra>","legendgroup":"\u043f\u043e\u043b\u043d\u044b\u0439 \u0434\u0435\u043d\u044c","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"\u043f\u043e\u043b\u043d\u044b\u0439 \u0434\u0435\u043d\u044c (81.39% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)","offsetgroup":"\u043f\u043e\u043b\u043d\u044b\u0439 \u0434\u0435\u043d\u044c","orientation":"v","showlegend":true,"text":[1045.0],"textposition":"outside","x":["\u043f\u043e\u043b\u043d\u044b\u0439 \u0434\u0435\u043d\u044c"],"xaxis":"x","y":[1045],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"skill=%{x}<br>vacancies=%{text}<extra></extra>","legendgroup":"\u0443\u0434\u0430\u043b\u0435\u043d\u043d\u0430\u044f \u0440\u0430\u0431\u043e\u0442\u0430","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"\u0443\u0434\u0430\u043b\u0435\u043d\u043d\u0430\u044f \u0440\u0430\u0431\u043e\u0442\u0430 (15.89% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)","offsetgroup":"\u0443\u0434\u0430\u043b\u0435\u043d\u043d\u0430\u044f \u0440\u0430\u0431\u043e\u0442\u0430","orientation":"v","showlegend":true,"text":[204.0],"textposition":"outside","x":["\u0443\u0434\u0430\u043b\u0435\u043d\u043d\u0430\u044f \u0440\u0430\u0431\u043e\u0442\u0430"],"xaxis":"x","y":[204],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"skill=%{x}<br>vacancies=%{text}<extra></extra>","legendgroup":"\u0433\u0438\u0431\u043a\u0438\u0439 \u0433\u0440\u0430\u0444\u0438\u043a","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"\u0433\u0438\u0431\u043a\u0438\u0439 \u0433\u0440\u0430\u0444\u0438\u043a (2.49% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)","offsetgroup":"\u0433\u0438\u0431\u043a\u0438\u0439 \u0433\u0440\u0430\u0444\u0438\u043a","orientation":"v","showlegend":true,"text":[32.0],"textposition":"outside","x":["\u0433\u0438\u0431\u043a\u0438\u0439 \u0433\u0440\u0430\u0444\u0438\u043a"],"xaxis":"x","y":[32],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"skill=%{x}<br>vacancies=%{text}<extra></extra>","legendgroup":"\u0441\u043c\u0435\u043d\u043d\u044b\u0439 \u0433\u0440\u0430\u0444\u0438\u043a","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"\u0441\u043c\u0435\u043d\u043d\u044b\u0439 \u0433\u0440\u0430\u0444\u0438\u043a (0.23% \u0432\u0430\u043a\u0430\u043d\u0441\u0438\u0439)","offsetgroup":"\u0441\u043c\u0435\u043d\u043d\u044b\u0439 \u0433\u0440\u0430\u0444\u0438\u043a","orientation":"v","showlegend":true,"text":[3.0],"textposition":"outside","x":["\u0441\u043c\u0435\u043d\u043d\u044b\u0439 \u0433\u0440\u0430\u0444\u0438\u043a"],"xaxis":"x","y":[3],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.55 ...

# %% [markdown]
# **Выводы по исследовательскому анализу**
#
# 1. В ТОПе 15 ключевых навыков требуемых в профессии аналитик данных лидируют: sql, python, анализ данных, аналитическое мышление и power bi;
# 2. В ТОПе 15 ключевых навыков для бизнес аналитика лидируют: бизнес анализ, bpmn, аналитическое мышление, организация и моделирование бизнес процессов;
# 3. В зависимости от опыта в профессии аналитик данных требуются следующие навыки, перечислим по 5 наиболее востребованных:
#  - junior+ (1-3 years): sql, python, анализ данных, аналитическое мышление и ms excel;
#  - middle (3-6 years): sql, python, анализ данных, power bi и аналитическое мышление;
#  - junior (no experience): sql, ms excel, python, ms powerpoint и аналитическое мышление;
#  - senior : данные отсутствуют.
# 4. В зависимости от опыта в профессии бизнес аналитик требуются следующие навыки, перечислим по 5 наиболее востребованных:
#  - junior+ (1-3 years): бизнес анализ, bpmn, организация бизнес процессов, аналитическое мышление и sql;
#  - middle (3-6 years): бизнес анализ, bpmn, моделирование и оптимизация бизнес процессов и аналитическое мышление;
#  - junior (no experience): бизнес анализ, моделирование бизнес процессов, sql, аналитический склад ума и bpmn;
#  - senior: бизнес анализ, bpmn, sql, ms excel и start up project.
#  5. По работодателям в разрезе профессии лидируют следующие компании:
#  - аналитик данных: сбер, wildberries, t1, ozon и мтс;
#  - бизнес аналитик: сбер, розничная сеть, магнит, банк ВТБ и т1.
#  6. Среди городов лидируют:
#  - аналитик данных: Москва, Санкт-Петербург, Казань, Екатеринбург и Нижний Новгород;
#  - бизнес аналитик: Москва, Санкт-Петербург, Екатеринбург, Нижний Новгород и Казань.
#  7. Наиболее восребованы следующие виды занятости:
#  - аналитик данных: полный день(84%), удаленная работа(13,69%), гибкий график(1,68%) и сменный график(0,56%);
#  - бизнес аналитик: полный день(80,35%), удаленная работа(16,74%), гибкий график(2,81%) и сменный график(0,11%).

# %% [markdown]
# # Выводы по проекту
#
# На момент проведения анализа рынка всего в России по вакансиям аналитик данных и бизнес аналитик было 1284 открытых релевантных позиций в 640 компаниях. Из 1284 вакансий величина ЗП была указана в 142 случаях (11.06%)
#
# Так как данные были представлены за один месяц исследование динамики не проводилось. Также в связи с наличием 89% пропусков в заработной плате, анализ заработной платы не проводился.
#
# В зависимости от типа вакансии приоритеты ключевых навыков меняются, перечислим наиболее важные:
# - аналитик данных: sql, python, анализ данных, аналитическое мышление и power bi;
# - бизнес аналитик: бизнес анализ, bpmn, аналитическое мышление, организация и моделирование бизнес процессов.
#
# В зависимости от опыта в профессии аналитик данных требуются следующие навыки:
# - junior+ (1-3 years): sql, python, анализ данных, аналитическое мышление и ms excel;
# - middle (3-6 years): sql, python, анализ данных, power bi и аналитическое мышление;
# - junior (no experience): sql, ms excel, python, ms powerpoint и аналитическое мышление.
# Можно сказать что для junior+ и middle востребованы примерно одинаковые навыки, а для junior (без опыта) желательно понимать еще ms excel и ms powerpoint.
#
# В профессии бизнес аналитик в разрезе опыта востребованы:
# - junior+ (1-3 years): бизнес анализ, bpmn, организация бизнес процессов, аналитическое мышление и sql;
# - middle (3-6 years): бизнес анализ, bpmn, моделирование и оптимизация бизнес процессов и аналитическое мышление;
# - junior (no experience): бизнес анализ, моделирование бизнес процессов, sql, аналитический склад ума и bpmn;
# - senior: бизнес анализ, bpmn, sql, ms excel и start up project.
#
# По работодателям в разрезе профессии лидируют следующие компании:
# - аналитик данных: сбер, wildberries, t1, ozon и мтс;
# - бизнес аналитик: сбер, розничная сеть, магнит, банк ВТБ и т1.
#
# При исследовании вакансий в разрезе городов можно сказать, что лидируют одни и те же города:
# - аналитик данных: Москва, Санкт-Петербург, Казань, Екатеринбург и Нижний Новгород;
# - бизнес аналитик: Москва, Санкт-Петербург, Екатеринбург, Нижний Новгород и Казань.
#
# При анализе требуемой занятости, мы видим, что лидирует с большим отрывом именно полная занятость, удаленный же тип занятости востребован относительно мало:
# - аналитик данных: полный день(84%), удаленная работа(13,69%), гибкий график(1,68%) и сменный график(0,56%);
# - бизнес аналитик: полный день(80,35%), удаленная работа(16,74%), гибкий график(2,81%) и сменный график(0,11%).
#
# Далее рассмотрим подтвердились ли наши гипотезы.
#
# 1. Большую долю вакансий занимают вакансии на позицию Junior с опытом от года.
# Эта гипотеза подтвердилась полностью.
# - junior+ (1-3 years)      675
# - middle (3-6 years)       505
# - junior (no experince)     92
# - senior (6+ years)         12
#
# 2. Москва лидирует по количеству вакансий.
# Данная гипотеза 100% подтвердилась, это видно при исследовании требуемых вакансий в разрезе городов.
#
# 3. Предложений на удаленную работу больше чем на работу в офисе.
# Гипотеза не подтвердилась. Большую долю занимают вакансии на полный день.
# - полный день         1045
# - удаленная работа     204
# - гибкий график         32
# - сменный график         3
#
# Сформулируем рекомендации по навыкам для соискателя без опыта(junior no experince).
#
# - Для поиска работы на должность аналитик данных необходимо знать: sql, python, ms excel, powerpoint и уметь мыслить аналитически.
#
# - На должность бизнес аналитик необходимо иметь следующие навыки: бизнес анализ, моделирование бизнес процессов, sql, аналитический склад ума и bpmn.
